# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
x_train = pd.read_csv(r"/kaggle/input/hijja-dataset/train_X.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/hijja-dataset/train_Y.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/hijja-dataset/test_X.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/hijja-dataset/test_Y.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (37933, 1024)
# y_train.shape = (37933, 1)
# x_test.shape = (9501, 1024)
# y_test.shape = (9501, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (37933, 1024)
# y_train.shape = (37933, 1)
# x_test.shape = (9501, 1024)
# y_test.shape = (9501, 1)

# %%
x_train = x_train.reshape(-1,32,32,1)
x_test = x_test.reshape(-1,32,32,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (37933, 32, 32, 1) (9501, 32, 32, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(20,20))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (37933, 30)
# (9501, 30)

# %%
model = Sequential([
    
    
    GRU(256, return_sequences=True, dropout=0.25, input_shape=(32,32)),
    Dense(256, activation='relu'),
    
    GRU(128, return_sequences=True, dropout=0.4),
    Dense(128, activation='relu'),
    
    GRU(64, return_sequences=True, dropout=0.6),
    Dense(64, activation='relu'),
    
    GRU(32, return_sequences=True, dropout=0.8),
    Dense(32, activation='relu'),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(total_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           222720
#
#  dense (Dense)               (None, 32, 256)           65792
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  dense_1 (Dense)             (None, 32, 128)           16512
#
#  gru_2 (GRU)                 (None, 32, 64)            37248
#
#  dense_2 (Dense)             (None, 32, 64)            4160
#
#  gru_3 (GRU)                 (None, 32, 32)            9408
#
#  dense_3 (Dense)             (None, 32, 32)            1056
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 810,622
# Trainable params: 810,622
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 297/297 [==============================] - 19s 22ms/step - loss: 2.9649 - accuracy: 0.1386 - val_loss: 2.4059 - val_accuracy: 0.2526
# Epoch 2/150
# 297/297 [==============================] - 5s 17ms/step - loss: 2.2757 - accuracy: 0.2969 - val_loss: 1.8726 - val_accuracy: 0.4067
# Epoch 3/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.9650 - accuracy: 0.3835 - val_loss: 1.5352 - val_accuracy: 0.4983
# Epoch 4/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.7505 - accuracy: 0.4516 - val_loss: 1.3720 - val_accuracy: 0.5575
# Epoch 5/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.5982 - accuracy: 0.4984 - val_loss: 1.2514 - val_accuracy: 0.6028
# Epoch 6/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.4866 - accuracy: 0.5305 - val_loss: 1.1712 - val_accuracy: 0.6307
# Epoch 7/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.4242 - accuracy: 0.5551 - val_loss: 1.2183 - val_accuracy: 0.6143
# Epoch 8/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.3479 - accuracy: 0.5760 - val_loss: 1.0404 - val_accuracy: 0.6737
# Epoch 9/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1.2959 - accuracy: 0.5953 - val_loss: 0.9646 - val_accuracy: 0.6987
# Epoch 10/150
# 297/297 [==============================] - 5s 17ms/step - loss: 1
150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.5030 - accuracy: 0.8438 - val_loss: 0.6996 - val_accuracy: 0.8097
# Epoch 142/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4859 - accuracy: 0.8472 - val_loss: 0.6763 - val_accuracy: 0.8087
# Epoch 143/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4918 - accuracy: 0.8459 - val_loss: 0.6750 - val_accuracy: 0.8139
# Epoch 144/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4896 - accuracy: 0.8472 - val_loss: 0.7037 - val_accuracy: 0.8035
# Epoch 145/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4922 - accuracy: 0.8493 - val_loss: 0.7036 - val_accuracy: 0.8061
# Epoch 146/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4906 - accuracy: 0.8473 - val_loss: 0.6996 - val_accuracy: 0.8122
# Epoch 147/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4926 - accuracy: 0.8455 - val_loss: 0.6987 - val_accuracy: 0.8035
# Epoch 148/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4870 - accuracy: 0.8482 - val_loss: 0.6736 - val_accuracy: 0.8123
# Epoch 149/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4833 - accuracy: 0.8497 - val_loss: 0.7352 - val_accuracy: 0.7984
# Epoch 150/150
# 297/297 [==============================] - 5s 17ms/step - loss: 0.4786 - accuracy: 0.8508 - val_loss: 0.6700 - val_accuracy: 0.8148

# %%
y_held_pred=model.predict(x_test)
# Out:
# 297/297 [==============================] - 3s 6ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (9501,)
# (9501,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 297/297 [==============================] - 2s 7ms/step - loss: 0.6700 - accuracy: 0.8148
# [0.6700007319450378, 0.8147563338279724]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 297/297 - 2s - loss: 0.6700 - accuracy: 0.8148 - 2s/epoch - 6ms/step
# [0.6700007319450378, 0.8147563338279724]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 1186/1186 [==============================] - 7s 6ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (37933,)
# (37933,)
# 1186/1186 - 7s - loss: 0.2583 - accuracy: 0.9269 - 7s/epoch - 6ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 297/297 [==============================] - 2s 6ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.1, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((28,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(28):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 28))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('GRU' , y_pred)
# Out:
# GRU Accuracy: 81.48%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            1       0.98      0.95      0.97       549
#            2       0.95      0.89      0.92       360
#            3       0.62      0.94      0.75       360
#            4       0.78      0.75      0.77       366
#            5       0.86      0.89      0.87       372
#            6       0.82      0.73      0.77       369
#            7       0.85      0.77      0.80       370
#            8       0.72      0.74      0.73       178
#            9       0.73      0.66      0.69       171
#           10       0.94      0.78      0.85       170
#           11       0.94      0.80      0.86       172
#           12       0.73      0.92      0.81       346
#           13       0.90      0.86      0.88       342
#           14       0.79      0.64      0.71       345
#           15       0.85      0.70      0.77       339
#           16       0.88      0.87      0.87       351
#           17       0.85      0.86      0.85       342
#           18       0.75      0.72      0.73       348
#           19       0.89      0.76      0.82       345
#           20       0.72      0.74      0.73       347
#           21       0.79      0.87      0.83       349
#           22       0.80      0.86      0.83       348
#           23       0.86      0.87      0.86       350
#           24       0.89      0.83      0.86       346
#           25       0.65      0.73      0.69       356
#           26       0.77      0.83      0.80       347
#           27       0.80      0.90      0.84       175
#           28       0.90      0.90      0.90       346
#           29       0.77      0.70      0.74       342
#
#     accuracy                           0.81      9501
#    macro avg       0.82      0.81      0.81      9501
# weighted avg       0.82      0.81      0.82      9501
