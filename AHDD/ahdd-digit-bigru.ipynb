# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix

# %%
x_train = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Train_dataset 60kx784.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Train_dataset (Label)60kx1.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Test_dataset 10kx784.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Test_dataset (Label) 10kx1.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(10,10))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 11)
# (10000, 11)

# %%
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input,Conv1D,Flatten,BatchNormalization,SpatialDropout1D, MaxPooling1D,Dense,GlobalMaxPooling1D,Embedding
class attention(layers.Layer):
    def _init_(self,**kwargs):
        super(attention,self)._init_(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %%
model = Sequential([
    
    
   Bidirectional(GRU(256, return_sequences=True, dropout=0.25), input_shape=(28,28)),
    Dense(256, activation='relu'),
    
    Bidirectional(GRU(128, return_sequences=True, dropout=0.5)),
    Dense(128, activation='relu'),
    
    Bidirectional(GRU(64, return_sequences=True, dropout=0.5)),
    Dense(64, activation='relu'),
    
    Bidirectional(GRU(32, return_sequences=True, dropout=0.5)),
    Dense(32, activation='relu'),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(total_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirecti  (None, 28, 512)           439296
#  onal)
#
#  dense_7 (Dense)             (None, 28, 256)           131328
#
#  bidirectional_5 (Bidirecti  (None, 28, 256)           296448
#  onal)
#
#  dense_8 (Dense)             (None, 28, 128)           32896
#
#  bidirectional_6 (Bidirecti  (None, 28, 128)           74496
#  onal)
#
#  dense_9 (Dense)             (None, 28, 64)            8256
#
#  bidirectional_7 (Bidirecti  (None, 28, 64)            18816
#  onal)
#
#  dense_10 (Dense)            (None, 28, 32)            2080
#
#  flatten_1 (Flatten)         (None, 896)               0
#
#  dense_11 (Dense)            (None, 128)               114816
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  dense_13 (Dense)            (None, 11)                2827
#
# =================================================================
# Total params: 1154283 (4.40 MB)
# Trainable params: 1154283 (4.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 469/469 [==============================] - 33s 32ms/step - loss: 0.2024 - accuracy: 0.9362 - val_loss: 0.0853 - val_accuracy: 0.9773
# Epoch 2/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0678 - accuracy: 0.9801 - val_loss: 0.0661 - val_accuracy: 0.9819
# Epoch 3/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0543 - accuracy: 0.9840 - val_loss: 0.0563 - val_accuracy: 0.9847
# Epoch 4/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0438 - accuracy: 0.9870 - val_loss: 0.0569 - val_accuracy: 0.9847
# Epoch 5/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0386 - accuracy: 0.9886 - val_loss: 0.0494 - val_accuracy: 0.9868
# Epoch 6/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0347 - accuracy: 0.9901 - val_loss: 0.0499 - val_accuracy: 0.9875
# Epoch 7/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0313 - accuracy: 0.9906 - val_loss: 0.0441 - val_accuracy: 0.9875
# Epoch 8/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0318 - accuracy: 0.9906 - val_loss: 0.0483 - val_accuracy: 0.9876
# Epoch 9/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0294 - accuracy: 0.9912 - val_loss: 0.0570 - val_accuracy: 0.9875
# Epoch 10/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0277 - accuracy: 0.9918 - val_loss: 0.0556 - val_accuracy: 0.9877
# Epoch 11/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.0563 - val_accuracy: 0.9880
# Epoch 12/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 0.0562 - val_accuracy: 0.9874
# Epoch 13/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 0.0493 - val_accuracy: 0.9890
# Epoch 14/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.0598 - val_accuracy: 0.9873
# Epoch 15/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0414 - val_accuracy: 0.9894
# Epoch 16/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.0403 - val_accuracy: 0.9907
# Epoch 17/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 0.0450 - val_accuracy: 0.9881
# Epoch 18/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0486 - val_accuracy: 0.9877
# Epoch 19/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.0468 - val_accuracy: 0.9883
# Epoch 20/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.0530 - val_accuracy: 0.9900
# Epoch 21/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.0583 - val_accuracy: 0.9883
# Epoch 22/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0191 - accuracy: 0.9942 - val_loss: 0.0534 - val_accuracy: 0.9886
# Epoch 23/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0443 - val_accuracy: 0.9898
# Epoch 24/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0479 - val_accuracy: 0.9901
# Epoch 25/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0188 - accuracy: 0.9942 - val_loss: 0.0457 - val_accuracy: 0.9888
# Epoch 26/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0600 - val_accuracy: 0.9886
# Epoch 27/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.0574 - val_accuracy: 0.9894
# Epoch 28/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0632 - val_accuracy: 0.9871
# Epoch 29/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0474 - val_accuracy: 0.9891
# Epoch 30/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0534 - val_accuracy: 0.9889
# Epoch 31/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.0515 - val_accuracy: 0.9902
# Epoch 32/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.0514 - val_accuracy: 0.9889
# Epoch 33/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0546 - val_accuracy: 0.9896
# Epoch 34/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0538 - val_accuracy: 0.9892
# Epoch 35/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0552 - val_accuracy: 0.9896
# Epoch 36/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0486 - val_accuracy: 0.9890
# Epoch 37/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0524 - val_accuracy: 0.9898
# Epoch 38/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0495 - val_accuracy: 0.9903
# Epoch 39/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.0495 - val_accuracy: 0.9903
# Epoch 40/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0606 - val_accuracy: 0.9888
# Epoch 41/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0576 - val_accuracy: 0.9888
# Epoch 42/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0585 - val_accuracy: 0.9886
# Epoch 43/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.0564 - val_accuracy: 0.9880
# Epoch 44/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.0627 - val_accuracy: 0.9878
# Epoch 45/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0577 - val_accuracy: 0.9884
# Epoch 46/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0560 - val_accuracy: 0.9888
# Epoch 47/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0582 - val_accuracy: 0.9893
# Epoch 48/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0615 - val_accuracy: 0.9872
# Epoch 49/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.0525 - val_accuracy: 0.9889
# Epoch 50/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0642 - val_accuracy: 0.9883
# Epoch 51/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0620 - val_accuracy: 0.9893
# Epoch 52/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0559 - val_accuracy: 0.9898
# Epoch 53/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0642 - val_accuracy: 0.9884
# Epoch 54/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0613 - val_accuracy: 0.9900
# Epoch 55/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0582 - val_accuracy: 0.9889
# Epoch 56/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0681 - val_accuracy: 0.9885
# Epoch 57/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0693 - val_accuracy: 0.9880
# Epoch 58/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0601 - val_accuracy: 0.9898
# Epoch 59/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0706 - val_accuracy: 0.9891
# Epoch 60/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0557 - val_accuracy: 0.9900
# Epoch 61/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0755 - val_accuracy: 0.9893
# Epoch 62/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0600 - val_accuracy: 0.9885
# Epoch 63/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.0652 - val_accuracy: 0.9892
# Epoch 64/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0646 - val_accuracy: 0.9883
# Epoch 65/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0708 - val_accuracy: 0.9884
# Epoch 66/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0662 - val_accuracy: 0.9899
# Epoch 67/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0613 - val_accuracy: 0.9893
# Epoch 68/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0708 - val_accuracy: 0.9877
# Epoch 69/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0641 - val_accuracy: 0.9895
# Epoch 70/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0839 - val_accuracy: 0.9880
# Epoch 71/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.0671 - val_accuracy: 0.9901
# Epoch 72/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0667 - val_accuracy: 0.9897
# Epoch 73/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0665 - val_accuracy: 0.9882
# Epoch 74/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.0659 - val_accuracy: 0.9875
# Epoch 75/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0725 - val_accuracy: 0.9888
# Epoch 76/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0617 - val_accuracy: 0.9892
# Epoch 77/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0717 - val_accuracy: 0.9877
# Epoch 78/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0627 - val_accuracy: 0.9886
# Epoch 79/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0691 - val_accuracy: 0.9872
# Epoch 80/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0734 - val_accuracy: 0.9884
# Epoch 81/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.0667 - val_accuracy: 0.9877
# Epoch 82/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0699 - val_accuracy: 0.9892
# Epoch 83/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0881 - val_accuracy: 0.9867
# Epoch 84/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0649 - val_accuracy: 0.9883
# Epoch 85/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 0.0621 - val_accuracy: 0.9891
# Epoch 86/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0699 - val_accuracy: 0.9886
# Epoch 87/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0798 - val_accuracy: 0.9876
# Epoch 88/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0722 - val_accuracy: 0.9882
# Epoch 89/150
# 469/469 [==============================] - 12s 27ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0812 - val_accuracy: 0.9875
# Epoch 90/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.0645 - val_accuracy: 0.9893
# Epoch 91/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0843 - val_accuracy: 0.9870
# Epoch 92/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0664 - val_accuracy: 0.9875
# Epoch 93/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.0709 - val_accuracy: 0.9879
# Epoch 94/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.0730 - val_accuracy: 0.9889
# Epoch 95/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0783 - val_accuracy: 0.9879
# Epoch 96/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0754 - val_accuracy: 0.9875
# Epoch 97/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.0677 - val_accuracy: 0.9890
# Epoch 98/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0780 - val_accuracy: 0.9869
# Epoch 99/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0694 - val_accuracy: 0.9893
# Epoch 100/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0715 - val_accuracy: 0.9877
# Epoch 101/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0720 - val_accuracy: 0.9882
# Epoch 102/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0702 - val_accuracy: 0.9874
# Epoch 103/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0699 - val_accuracy: 0.9880
# Epoch 104/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0666 - val_accuracy: 0.9881
# Epoch 105/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0545 - val_accuracy: 0.9891
# Epoch 106/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0722 - val_accuracy: 0.9896
# Epoch 107/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0639 - val_accuracy: 0.9893
# Epoch 108/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0604 - val_accuracy: 0.9893
# Epoch 109/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0823 - val_accuracy: 0.9868
# Epoch 110/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0710 - val_accuracy: 0.9888
# Epoch 111/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0853 - val_accuracy: 0.9881
# Epoch 112/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.0668 - val_accuracy: 0.9889
# Epoch 113/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0643 - val_accuracy: 0.9879
# Epoch 114/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0635 - val_accuracy: 0.9882
# Epoch 115/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0698 - val_accuracy: 0.9894
# Epoch 116/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0603 - val_accuracy: 0.9884
# Epoch 117/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0707 - val_accuracy: 0.9882
# Epoch 118/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0138 - accuracy: 0.9956 - val_loss: 0.0741 - val_accuracy: 0.9887
# Epoch 119/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0669 - val_accuracy: 0.9901
# Epoch 120/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0735 - val_accuracy: 0.9886
# Epoch 121/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0563 - val_accuracy: 0.9897
# Epoch 122/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.0621 - val_accuracy: 0.9880
# Epoch 123/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0700 - val_accuracy: 0.9880
# Epoch 124/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0674 - val_accuracy: 0.9888
# Epoch 125/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0572 - val_accuracy: 0.9895
# Epoch 126/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0718 - val_accuracy: 0.9884
# Epoch 127/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.0608 - val_accuracy: 0.9889
# Epoch 128/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0665 - val_accuracy: 0.9883
# Epoch 129/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.0593 - val_accuracy: 0.9882
# Epoch 130/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0625 - val_accuracy: 0.9886
# Epoch 131/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0664 - val_accuracy: 0.9888
# Epoch 132/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.0696 - val_accuracy: 0.9886
# Epoch 133/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0853 - val_accuracy: 0.9864
# Epoch 134/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0699 - val_accuracy: 0.9885
# Epoch 135/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0787 - val_accuracy: 0.9870
# Epoch 136/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0607 - val_accuracy: 0.9892
# Epoch 137/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0651 - val_accuracy: 0.9873
# Epoch 138/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0140 - accuracy: 0.9956 - val_loss: 0.0651 - val_accuracy: 0.9894
# Epoch 139/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.0629 - val_accuracy: 0.9897
# Epoch 140/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0673 - val_accuracy: 0.9894
# Epoch 141/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0600 - val_accuracy: 0.9894
# Epoch 142/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0581 - val_accuracy: 0.9883
# Epoch 143/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0687 - val_accuracy: 0.9889
# Epoch 144/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0688 - val_accuracy: 0.9895
# Epoch 145/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.0602 - val_accuracy: 0.9890
# Epoch 146/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0689 - val_accuracy: 0.9883
# Epoch 147/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.0707 - val_accuracy: 0.9878
# Epoch 148/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.0684 - val_accuracy: 0.9874
# Epoch 149/150
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0773 - val_accuracy: 0.9895
# Epoch 150/150
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 0.0647 - val_accuracy: 0.9873

# %%
y_held_pred=model.predict(x_test)
# Out:
# 313/313 [==============================] - 5s 9ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (10000,)
# (10000,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0647 - accuracy: 0.9873
# [0.06473153829574585, 0.9872999787330627]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 313/313 - 3s - loss: 0.0647 - accuracy: 0.9873 - 3s/epoch - 9ms/step
# [0.06473153829574585, 0.9872999787330627]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 1875/1875 [==============================] - 17s 9ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (60000,)
# (60000,)
# 1875/1875 - 17s - loss: 0.0067 - accuracy: 0.9977 - 17s/epoch - 9ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 313/313 [==============================] - 3s 9ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.2, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((10,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(10):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 10))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('LSTM' , y_pred)
# Out:
# LSTM Accuracy: 98.73%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1000
#            1       0.98      0.99      0.98      1000
#            2       0.97      0.99      0.98      1000
#            3       1.00      0.98      0.99      1000
#            4       1.00      0.98      0.99      1000
#            5       0.98      0.98      0.98      1000
#            6       0.99      0.98      0.99      1000
#            7       1.00      1.00      1.00      1000
#            8       0.99      1.00      1.00      1000
#            9       0.99      0.99      0.99      1000
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ###
