# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/Test_dataset 10kx784.csv
# /kaggle/input/Arabic Handwritten Digits Dataset.txt
# /kaggle/input/Train_dataset 60kx784.csv
# /kaggle/input/Train_dataset (Label)60kx1.csv
# /kaggle/input/Test_dataset (Label) 10kx1.csv

# %%
x_train = pd.read_csv(r"/kaggle/input/Train_dataset 60kx784.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/Train_dataset (Label)60kx1.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/Test_dataset 10kx784.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/Test_dataset (Label) 10kx1.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(10,10))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 11)
# (10000, 11)

# %%
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input,Conv1D,Flatten,BatchNormalization,SpatialDropout1D, MaxPooling1D,Dense,GlobalMaxPooling1D,Embedding,Bidirectional
class attention(layers.Layer):
    def _init_(self,**kwargs):
        super(attention,self)._init_(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %%
model = Sequential([
    
    
   Bidirectional(LSTM(256, return_sequences=True, dropout=0.25), input_shape=(28,28)),
    Dense(256, activation='relu'),
    
    Bidirectional(LSTM(128, return_sequences=True, dropout=0.5)),
    Dense(128, activation='relu'),
    
    Bidirectional(LSTM(64, return_sequences=True, dropout=0.5)),
    Dense(64, activation='relu'),
    
    Bidirectional(LSTM(32, return_sequences=True, dropout=0.5)),
    Dense(32, activation='relu'),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(total_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 28, 512)           583680
#  al)
#
#  dense (Dense)               (None, 28, 256)           131328
#
#  bidirectional_1 (Bidirecti  (None, 28, 256)           394240
#  onal)
#
#  dense_1 (Dense)             (None, 28, 128)           32896
#
#  bidirectional_2 (Bidirecti  (None, 28, 128)           98816
#  onal)
#
#  dense_2 (Dense)             (None, 28, 64)            8256
#
#  bidirectional_3 (Bidirecti  (None, 28, 64)            24832
#  onal)
#
#  dense_3 (Dense)             (None, 28, 32)            2080
#
#  flatten (Flatten)           (None, 896)               0
#
#  dense_4 (Dense)             (None, 128)               114816
#
#  dense_5 (Dense)             (None, 256)               33024
#
#  dense_6 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 1426795 (5.44 MB)
# Trainable params: 1426795 (5.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 469/469 [==============================] - 34s 34ms/step - loss: 0.2792 - accuracy: 0.9095 - val_loss: 0.0876 - val_accuracy: 0.9752
# Epoch 2/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0744 - accuracy: 0.9785 - val_loss: 0.0648 - val_accuracy: 0.9798
# Epoch 3/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0585 - accuracy: 0.9826 - val_loss: 0.0707 - val_accuracy: 0.9805
# Epoch 4/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0470 - accuracy: 0.9866 - val_loss: 0.0476 - val_accuracy: 0.9867
# Epoch 5/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0421 - accuracy: 0.9882 - val_loss: 0.0465 - val_accuracy: 0.9882
# Epoch 6/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0399 - accuracy: 0.9885 - val_loss: 0.0612 - val_accuracy: 0.9852
# Epoch 7/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0366 - accuracy: 0.9894 - val_loss: 0.0612 - val_accuracy: 0.9845
# Epoch 8/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0360 - accuracy: 0.9900 - val_loss: 0.0569 - val_accuracy: 0.9837
# Epoch 9/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0326 - accuracy: 0.9906 - val_loss: 0.0409 - val_accuracy: 0.9879
# Epoch 10/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 0.0485 - val_accuracy: 0.9880
# Epoch 11/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0549 - val_accuracy: 0.9867
# Epoch 12/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.0669 - val_accuracy: 0.9876
# Epoch 13/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0265 - accuracy: 0.9926 - val_loss: 0.0429 - val_accuracy: 0.9899
# Epoch 14/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 0.0479 - val_accuracy: 0.9885
# Epoch 15/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0624 - val_accuracy: 0.9852
# Epoch 16/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0230 - accuracy: 0.9933 - val_loss: 0.0490 - val_accuracy: 0.9891
# Epoch 17/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0213 - accuracy: 0.9939 - val_loss: 0.0396 - val_accuracy: 0.9899
# Epoch 18/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0187 - accuracy: 0.9943 - val_loss: 0.0550 - val_accuracy: 0.9892
# Epoch 19/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0201 - accuracy: 0.9941 - val_loss: 0.0459 - val_accuracy: 0.9896
# Epoch 20/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0440 - val_accuracy: 0.9892
# Epoch 21/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0449 - val_accuracy: 0.9893
# Epoch 22/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.0600 - val_accuracy: 0.9878
# Epoch 23/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0194 - accuracy: 0.9943 - val_loss: 0.0530 - val_accuracy: 0.9879
# Epoch 24/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0174 - accuracy: 0.9949 - val_loss: 0.0450 - val_accuracy: 0.9898
# Epoch 25/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0487 - val_accuracy: 0.9904
# Epoch 26/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0537 - val_accuracy: 0.9897
# Epoch 27/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.0447 - val_accuracy: 0.9905
# Epoch 28/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 0.0482 - val_accuracy: 0.9892
# Epoch 29/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.0409 - val_accuracy: 0.9911
# Epoch 30/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.0468 - val_accuracy: 0.9905
# Epoch 31/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.0474 - val_accuracy: 0.9895
# Epoch 32/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0716 - val_accuracy: 0.9882
# Epoch 33/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0543 - val_accuracy: 0.9895
# Epoch 34/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0479 - val_accuracy: 0.9906
# Epoch 35/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0448 - val_accuracy: 0.9902
# Epoch 36/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0489 - val_accuracy: 0.9914
# Epoch 37/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0481 - val_accuracy: 0.9909
# Epoch 38/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0511 - val_accuracy: 0.9907
# Epoch 39/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0593 - val_accuracy: 0.9901
# Epoch 40/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0523 - val_accuracy: 0.9913
# Epoch 41/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0126 - accuracy: 0.9964 - val_loss: 0.0454 - val_accuracy: 0.9902
# Epoch 42/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.0614 - val_accuracy: 0.9907
# Epoch 43/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.0552 - val_accuracy: 0.9902
# Epoch 44/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0582 - val_accuracy: 0.9901
# Epoch 45/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0521 - val_accuracy: 0.9910
# Epoch 46/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0470 - val_accuracy: 0.9902
# Epoch 47/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0461 - val_accuracy: 0.9907
# Epoch 48/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0493 - val_accuracy: 0.9905
# Epoch 49/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.0616 - val_accuracy: 0.9900
# Epoch 50/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0618 - val_accuracy: 0.9906
# Epoch 51/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.0549 - val_accuracy: 0.9903
# Epoch 52/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0523 - val_accuracy: 0.9903
# Epoch 53/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.0575 - val_accuracy: 0.9910
# Epoch 54/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.0623 - val_accuracy: 0.9894
# Epoch 55/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0613 - val_accuracy: 0.9886
# Epoch 56/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0624 - val_accuracy: 0.9903
# Epoch 57/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0089 - accuracy: 0.9976 - val_loss: 0.0522 - val_accuracy: 0.9907
# Epoch 58/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0584 - val_accuracy: 0.9909
# Epoch 59/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0583 - val_accuracy: 0.9891
# Epoch 60/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0566 - val_accuracy: 0.9896
# Epoch 61/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0650 - val_accuracy: 0.9911
# Epoch 62/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0590 - val_accuracy: 0.9897
# Epoch 63/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0633 - val_accuracy: 0.9900
# Epoch 64/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0700 - val_accuracy: 0.9896
# Epoch 65/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0760 - val_accuracy: 0.9908
# Epoch 66/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0572 - val_accuracy: 0.9886
# Epoch 67/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0659 - val_accuracy: 0.9889
# Epoch 68/150
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.0615 - val_accuracy: 0.9900
# Epoch 69/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0681 - val_accuracy: 0.9895
# Epoch 70/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0694 - val_accuracy: 0.9897
# Epoch 71/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0539 - val_accuracy: 0.9908
# Epoch 72/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0526 - val_accuracy: 0.9915
# Epoch 73/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0683 - val_accuracy: 0.9903
# Epoch 74/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0655 - val_accuracy: 0.9901
# Epoch 75/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0630 - val_accuracy: 0.9904
# Epoch 76/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0770 - val_accuracy: 0.9893
# Epoch 77/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0644 - val_accuracy: 0.9901
# Epoch 78/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0596 - val_accuracy: 0.9913
# Epoch 79/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0595 - val_accuracy: 0.9919
# Epoch 80/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0553 - val_accuracy: 0.9908
# Epoch 81/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0629 - val_accuracy: 0.9917
# Epoch 82/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0562 - val_accuracy: 0.9911
# Epoch 83/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0586 - val_accuracy: 0.9897
# Epoch 84/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0589 - val_accuracy: 0.9900
# Epoch 85/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0689 - val_accuracy: 0.9891
# Epoch 86/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0575 - val_accuracy: 0.9909
# Epoch 87/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0658 - val_accuracy: 0.9906
# Epoch 88/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0582 - val_accuracy: 0.9912
# Epoch 89/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0814 - val_accuracy: 0.9904
# Epoch 90/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0585 - val_accuracy: 0.9907
# Epoch 91/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0635 - val_accuracy: 0.9903
# Epoch 92/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0660 - val_accuracy: 0.9912
# Epoch 93/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0591 - val_accuracy: 0.9902
# Epoch 94/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0727 - val_accuracy: 0.9904
# Epoch 95/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0745 - val_accuracy: 0.9901
# Epoch 96/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0687 - val_accuracy: 0.9906
# Epoch 97/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0736 - val_accuracy: 0.9903
# Epoch 98/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0702 - val_accuracy: 0.9903
# Epoch 99/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0681 - val_accuracy: 0.9902
# Epoch 100/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0705 - val_accuracy: 0.9909
# Epoch 101/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0761 - val_accuracy: 0.9901
# Epoch 102/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0793 - val_accuracy: 0.9899
# Epoch 103/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0670 - val_accuracy: 0.9904
# Epoch 104/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0738 - val_accuracy: 0.9905
# Epoch 105/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0726 - val_accuracy: 0.9910
# Epoch 106/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0743 - val_accuracy: 0.9907
# Epoch 107/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0848 - val_accuracy: 0.9908
# Epoch 108/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0542 - val_accuracy: 0.9916
# Epoch 109/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0689 - val_accuracy: 0.9907
# Epoch 110/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0660 - val_accuracy: 0.9908
# Epoch 111/150
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0721 - val_accuracy: 0.9908
# Epoch 112/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0514 - val_accuracy: 0.9918
# Epoch 113/150
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0728 - val_accuracy: 0.9907
# Epoch 114/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0752 - val_accuracy: 0.9900
# Epoch 115/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0811 - val_accuracy: 0.9896
# Epoch 116/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0746 - val_accuracy: 0.9906
# Epoch 117/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0821 - val_accuracy: 0.9897
# Epoch 118/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0665 - val_accuracy: 0.9900
# Epoch 119/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0737 - val_accuracy: 0.9896
# Epoch 120/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0798 - val_accuracy: 0.9900
# Epoch 121/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0687 - val_accuracy: 0.9889
# Epoch 122/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0724 - val_accuracy: 0.9903
# Epoch 123/150
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0726 - val_accuracy: 0.9902
# Epoch 124/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0780 - val_accuracy: 0.9899
# Epoch 125/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0646 - val_accuracy: 0.9898
# Epoch 126/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0610 - val_accuracy: 0.9900
# Epoch 127/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0685 - val_accuracy: 0.9903
# Epoch 128/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0806 - val_accuracy: 0.9900
# Epoch 129/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0720 - val_accuracy: 0.9905
# Epoch 130/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0761 - val_accuracy: 0.9905
# Epoch 131/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0774 - val_accuracy: 0.9895
# Epoch 132/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0885 - val_accuracy: 0.9892
# Epoch 133/150
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0724 - val_accuracy: 0.9898
# Epoch 134/150
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0737 - val_accuracy: 0.9911
# Epoch 135/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0785 - val_accuracy: 0.9889
# Epoch 136/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0704 - val_accuracy: 0.9907
# Epoch 137/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0680 - val_accuracy: 0.9907
# Epoch 138/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0752 - val_accuracy: 0.9905
# Epoch 139/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0580 - val_accuracy: 0.9905
# Epoch 140/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0560 - val_accuracy: 0.9912
# Epoch 141/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0631 - val_accuracy: 0.9905
# Epoch 142/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0642 - val_accuracy: 0.9904
# Epoch 143/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0653 - val_accuracy: 0.9918
# Epoch 144/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0666 - val_accuracy: 0.9913
# Epoch 145/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0772 - val_accuracy: 0.9904
# Epoch 146/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0575 - val_accuracy: 0.9907
# Epoch 147/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0714 - val_accuracy: 0.9905
# Epoch 148/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.0854 - val_accuracy: 0.9902
# Epoch 149/150
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0915 - val_accuracy: 0.9885
# Epoch 150/150
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0675 - val_accuracy: 0.9898

# %%
y_held_pred=model.predict(x_test)
# Out:
# 313/313 [==============================] - 6s 10ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (10000,)
# (10000,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0675 - accuracy: 0.9898
# [0.06748374551534653, 0.989799976348877]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 313/313 - 3s - loss: 0.0675 - accuracy: 0.9898 - 3s/epoch - 10ms/step
# [0.06748374551534653, 0.989799976348877]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 1875/1875 [==============================] - 18s 9ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (60000,)
# (60000,)
# 1875/1875 - 18s - loss: 0.0011 - accuracy: 0.9998 - 18s/epoch - 9ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 313/313 [==============================] - 3s 10ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.2, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((10,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(10):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 10))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('Bi-LSTM' , y_pred)
# Out:
# Bi-LSTM Accuracy: 98.98%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1000
#            1       0.99      0.98      0.98      1000
#            2       0.98      0.99      0.98      1000
#            3       1.00      0.99      0.99      1000
#            4       1.00      0.99      0.99      1000
#            5       0.99      0.98      0.98      1000
#            6       1.00      0.99      0.99      1000
#            7       1.00      1.00      1.00      1000
#            8       1.00      0.99      1.00      1000
#            9       0.99      0.99      0.99      1000
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ###
