# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
x_train = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Train_dataset 60kx784.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Train_dataset (Label)60kx1.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Test_dataset 10kx784.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/arabic-handwritten-digits-dataset-ahdd/Test_dataset (Label) 10kx1.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(5,5))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 11)
# (10000, 11)

# %%
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input,Conv1D,Flatten,BatchNormalization,SpatialDropout1D, MaxPooling1D,Dense,GlobalMaxPooling1D,Embedding
class attention(layers.Layer):
    def _init_(self,**kwargs):
        super(attention,self)._init_(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %%
model = Sequential([
    
    
    GRU(256, return_sequences=True, dropout=0.25, input_shape=(28,28)),
    Dense(256, activation='relu'),
    
    GRU(128, return_sequences=True, dropout=0.5),
    Dense(128, activation='relu'),
    
    GRU(64, return_sequences=True, dropout=0.5),
    Dense(64, activation='relu'),
    
    GRU(32, return_sequences=True, dropout=0.5),
    Dense(32, activation='relu'),
    
    attention(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(total_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 28, 256)           219648
#
#  dense (Dense)               (None, 28, 256)           65792
#
#  gru_1 (GRU)                 (None, 28, 128)           148224
#
#  dense_1 (Dense)             (None, 28, 128)           16512
#
#  gru_2 (GRU)                 (None, 28, 64)            37248
#
#  dense_2 (Dense)             (None, 28, 64)            4160
#
#  gru_3 (GRU)                 (None, 28, 32)            9408
#
#  dense_3 (Dense)             (None, 28, 32)            1056
#
#  attention (attention)       (None, 32)                60
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 128)               4224
#
#  dense_5 (Dense)             (None, 256)               33024
#
#  dense_6 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 542183 (2.07 MB)
# Trainable params: 542183 (2.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 469/469 [==============================] - 21s 18ms/step - loss: 0.6025 - accuracy: 0.7989 - val_loss: 0.1858 - val_accuracy: 0.9499
# Epoch 2/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.1226 - accuracy: 0.9661 - val_loss: 0.1039 - val_accuracy: 0.9726
# Epoch 3/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0826 - accuracy: 0.9768 - val_loss: 0.0803 - val_accuracy: 0.9792
# Epoch 4/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0637 - accuracy: 0.9822 - val_loss: 0.0611 - val_accuracy: 0.9842
# Epoch 5/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0566 - accuracy: 0.9835 - val_loss: 0.0664 - val_accuracy: 0.9833
# Epoch 6/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0498 - accuracy: 0.9860 - val_loss: 0.0645 - val_accuracy: 0.9825
# Epoch 7/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0454 - accuracy: 0.9872 - val_loss: 0.0533 - val_accuracy: 0.9855
# Epoch 8/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0432 - accuracy: 0.9879 - val_loss: 0.0553 - val_accuracy: 0.9866
# Epoch 9/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0388 - accuracy: 0.9892 - val_loss: 0.0496 - val_accuracy: 0.9871
# Epoch 10/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0389 - accuracy: 0.9889 - val_loss: 0.0443 - val_accuracy: 0.9885
# Epoch 11/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0354 - accuracy: 0.9899 - val_loss: 0.0535 - val_accuracy: 0.9878
# Epoch 12/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0332 - accuracy: 0.9908 - val_loss: 0.0553 - val_accuracy: 0.9870
# Epoch 13/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.0637 - val_accuracy: 0.9852
# Epoch 14/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0324 - accuracy: 0.9908 - val_loss: 0.0576 - val_accuracy: 0.9861
# Epoch 15/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0303 - accuracy: 0.9911 - val_loss: 0.0494 - val_accuracy: 0.9868
# Epoch 16/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0283 - accuracy: 0.9918 - val_loss: 0.0390 - val_accuracy: 0.9905
# Epoch 17/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0243 - accuracy: 0.9929 - val_loss: 0.0492 - val_accuracy: 0.9884
# Epoch 18/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0255 - accuracy: 0.9927 - val_loss: 0.0442 - val_accuracy: 0.9892
# Epoch 19/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0240 - accuracy: 0.9930 - val_loss: 0.0531 - val_accuracy: 0.9875
# Epoch 20/150
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0239 - accuracy: 0.9928 - val_loss: 0.0526 - val_accuracy: 0.9873
# Epoch 21/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.0487 - val_accuracy: 0.9876
# Epoch 22/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0230 - accuracy: 0.9936 - val_loss: 0.0453 - val_accuracy: 0.9895
# Epoch 23/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 0.0435 - val_accuracy: 0.9887
# Epoch 24/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0206 - accuracy: 0.9940 - val_loss: 0.0475 - val_accuracy: 0.9902
# Epoch 25/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0208 - accuracy: 0.9939 - val_loss: 0.0482 - val_accuracy: 0.9886
# Epoch 26/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0221 - accuracy: 0.9936 - val_loss: 0.0395 - val_accuracy: 0.9901
# Epoch 27/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.0493 - val_accuracy: 0.9900
# Epoch 28/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0187 - accuracy: 0.9944 - val_loss: 0.0577 - val_accuracy: 0.9889
# Epoch 29/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0194 - accuracy: 0.9942 - val_loss: 0.0466 - val_accuracy: 0.9899
# Epoch 30/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 0.0531 - val_accuracy: 0.9898
# Epoch 31/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0194 - accuracy: 0.9944 - val_loss: 0.0470 - val_accuracy: 0.9897
# Epoch 32/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.0430 - val_accuracy: 0.9896
# Epoch 33/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0196 - accuracy: 0.9945 - val_loss: 0.0540 - val_accuracy: 0.9888
# Epoch 34/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0191 - accuracy: 0.9945 - val_loss: 0.0591 - val_accuracy: 0.9881
# Epoch 35/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.0508 - val_accuracy: 0.9909
# Epoch 36/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 0.0489 - val_accuracy: 0.9903
# Epoch 37/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0576 - val_accuracy: 0.9890
# Epoch 38/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0178 - accuracy: 0.9949 - val_loss: 0.0633 - val_accuracy: 0.9893
# Epoch 39/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0181 - accuracy: 0.9950 - val_loss: 0.0555 - val_accuracy: 0.9882
# Epoch 40/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0483 - val_accuracy: 0.9902
# Epoch 41/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.0426 - val_accuracy: 0.9899
# Epoch 42/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.0535 - val_accuracy: 0.9892
# Epoch 43/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.0471 - val_accuracy: 0.9909
# Epoch 44/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.0575 - val_accuracy: 0.9892
# Epoch 45/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0494 - val_accuracy: 0.9890
# Epoch 46/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0671 - val_accuracy: 0.9880
# Epoch 47/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.0506 - val_accuracy: 0.9900
# Epoch 48/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.0533 - val_accuracy: 0.9896
# Epoch 49/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0512 - val_accuracy: 0.9904
# Epoch 50/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0601 - val_accuracy: 0.9885
# Epoch 51/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0554 - val_accuracy: 0.9888
# Epoch 52/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0492 - val_accuracy: 0.9903
# Epoch 53/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0158 - accuracy: 0.9959 - val_loss: 0.0565 - val_accuracy: 0.9901
# Epoch 54/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.0632 - val_accuracy: 0.9887
# Epoch 55/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0531 - val_accuracy: 0.9896
# Epoch 56/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0688 - val_accuracy: 0.9866
# Epoch 57/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0530 - val_accuracy: 0.9902
# Epoch 58/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.0540 - val_accuracy: 0.9894
# Epoch 59/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.0592 - val_accuracy: 0.9895
# Epoch 60/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0639 - val_accuracy: 0.9891
# Epoch 61/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.0624 - val_accuracy: 0.9886
# Epoch 62/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.0599 - val_accuracy: 0.9894
# Epoch 63/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0693 - val_accuracy: 0.9876
# Epoch 64/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.0615 - val_accuracy: 0.9887
# Epoch 65/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0634 - val_accuracy: 0.9904
# Epoch 66/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0599 - val_accuracy: 0.9903
# Epoch 67/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 0.0641 - val_accuracy: 0.9884
# Epoch 68/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0594 - val_accuracy: 0.9885
# Epoch 69/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0671 - val_accuracy: 0.9888
# Epoch 70/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0139 - accuracy: 0.9962 - val_loss: 0.0627 - val_accuracy: 0.9898
# Epoch 71/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.0571 - val_accuracy: 0.9900
# Epoch 72/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0735 - val_accuracy: 0.9878
# Epoch 73/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0694 - val_accuracy: 0.9890
# Epoch 74/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0665 - val_accuracy: 0.9897
# Epoch 75/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.0724 - val_accuracy: 0.9895
# Epoch 76/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0593 - val_accuracy: 0.9900
# Epoch 77/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0630 - val_accuracy: 0.9885
# Epoch 78/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.0663 - val_accuracy: 0.9900
# Epoch 79/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0784 - val_accuracy: 0.9893
# Epoch 80/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0517 - val_accuracy: 0.9896
# Epoch 81/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 0.0746 - val_accuracy: 0.9891
# Epoch 82/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0648 - val_accuracy: 0.9904
# Epoch 83/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0579 - val_accuracy: 0.9892
# Epoch 84/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0558 - val_accuracy: 0.9897
# Epoch 85/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0601 - val_accuracy: 0.9899
# Epoch 86/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0614 - val_accuracy: 0.9895
# Epoch 87/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0716 - val_accuracy: 0.9902
# Epoch 88/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0787 - val_accuracy: 0.9887
# Epoch 89/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0660 - val_accuracy: 0.9894
# Epoch 90/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.0667 - val_accuracy: 0.9899
# Epoch 91/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0558 - val_accuracy: 0.9896
# Epoch 92/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.0685 - val_accuracy: 0.9894
# Epoch 93/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.0597 - val_accuracy: 0.9891
# Epoch 94/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0501 - val_accuracy: 0.9907
# Epoch 95/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0575 - val_accuracy: 0.9901
# Epoch 96/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0601 - val_accuracy: 0.9891
# Epoch 97/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0586 - val_accuracy: 0.9898
# Epoch 98/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0564 - val_accuracy: 0.9906
# Epoch 99/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0721 - val_accuracy: 0.9884
# Epoch 100/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0595 - val_accuracy: 0.9892
# Epoch 101/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.0617 - val_accuracy: 0.9897
# Epoch 102/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0119 - accuracy: 0.9968 - val_loss: 0.0657 - val_accuracy: 0.9896
# Epoch 103/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.0625 - val_accuracy: 0.9900
# Epoch 104/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0705 - val_accuracy: 0.9884
# Epoch 105/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.0664 - val_accuracy: 0.9898
# Epoch 106/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0634 - val_accuracy: 0.9896
# Epoch 107/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0598 - val_accuracy: 0.9894
# Epoch 108/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0610 - val_accuracy: 0.9898
# Epoch 109/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0715 - val_accuracy: 0.9887
# Epoch 110/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0724 - val_accuracy: 0.9892
# Epoch 111/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0777 - val_accuracy: 0.9865
# Epoch 112/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.0609 - val_accuracy: 0.9893
# Epoch 113/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0669 - val_accuracy: 0.9895
# Epoch 114/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0672 - val_accuracy: 0.9886
# Epoch 115/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0607 - val_accuracy: 0.9906
# Epoch 116/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0126 - accuracy: 0.9964 - val_loss: 0.0753 - val_accuracy: 0.9892
# Epoch 117/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0722 - val_accuracy: 0.9883
# Epoch 118/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0749 - val_accuracy: 0.9872
# Epoch 119/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0726 - val_accuracy: 0.9871
# Epoch 120/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0812 - val_accuracy: 0.9889
# Epoch 121/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.0641 - val_accuracy: 0.9895
# Epoch 122/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0765 - val_accuracy: 0.9869
# Epoch 123/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0873 - val_accuracy: 0.9872
# Epoch 124/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0711 - val_accuracy: 0.9886
# Epoch 125/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0627 - val_accuracy: 0.9882
# Epoch 126/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0711 - val_accuracy: 0.9891
# Epoch 127/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0677 - val_accuracy: 0.9890
# Epoch 128/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0580 - val_accuracy: 0.9894
# Epoch 129/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.0647 - val_accuracy: 0.9877
# Epoch 130/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0148 - accuracy: 0.9959 - val_loss: 0.0677 - val_accuracy: 0.9878
# Epoch 131/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0513 - val_accuracy: 0.9884
# Epoch 132/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0657 - val_accuracy: 0.9890
# Epoch 133/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0680 - val_accuracy: 0.9893
# Epoch 134/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0648 - val_accuracy: 0.9897
# Epoch 135/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0668 - val_accuracy: 0.9893
# Epoch 136/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0754 - val_accuracy: 0.9878
# Epoch 137/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0735 - val_accuracy: 0.9874
# Epoch 138/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.0612 - val_accuracy: 0.9882
# Epoch 139/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0643 - val_accuracy: 0.9883
# Epoch 140/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0724 - val_accuracy: 0.9890
# Epoch 141/150
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0685 - val_accuracy: 0.9880
# Epoch 142/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0592 - val_accuracy: 0.9894
# Epoch 143/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0677 - val_accuracy: 0.9890
# Epoch 144/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.0589 - val_accuracy: 0.9901
# Epoch 145/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0683 - val_accuracy: 0.9887
# Epoch 146/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.0557 - val_accuracy: 0.9900
# Epoch 147/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0636 - val_accuracy: 0.9864
# Epoch 148/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.0650 - val_accuracy: 0.9892
# Epoch 149/150
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.0563 - val_accuracy: 0.9909
# Epoch 150/150
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0582 - val_accuracy: 0.9897

# %%
y_held_pred=model.predict(x_test)
# Out:
# 313/313 [==============================] - 3s 6ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (10000,)
# (10000,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0582 - accuracy: 0.9897
# [0.058224085718393326, 0.9897000193595886]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 313/313 - 2s - loss: 0.0582 - accuracy: 0.9897 - 2s/epoch - 6ms/step
# [0.058224085718393326, 0.9897000193595886]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 1875/1875 [==============================] - 11s 6ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (60000,)
# (60000,)
# 1875/1875 - 12s - loss: 0.0055 - accuracy: 0.9983 - 12s/epoch - 6ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.2, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((10,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(10):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 10))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('GRU' , y_pred)
# Out:
# GRU Accuracy: 98.97%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      1000
#            1       0.99      0.98      0.99      1000
#            2       0.97      0.99      0.98      1000
#            3       1.00      0.99      0.99      1000
#            4       0.99      0.99      0.99      1000
#            5       0.98      0.98      0.98      1000
#            6       1.00      0.99      0.99      1000
#            7       1.00      1.00      1.00      1000
#            8       1.00      0.99      1.00      1000
#            9       1.00      0.99      1.00      1000
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ###
