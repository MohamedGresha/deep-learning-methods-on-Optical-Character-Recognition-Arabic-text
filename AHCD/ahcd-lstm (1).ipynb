# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
x_train = pd.read_csv(r"/kaggle/input/ahcd1/csvTrainImages 13440x1024.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/ahcd1/csvTrainLabel 13440x1.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/ahcd1/csvTestImages 3360x1024.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/ahcd1/csvTestLabel 3360x1.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
x_train = x_train.reshape(-1,32,32,1)
x_test = x_test.reshape(-1,32,32,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (13440, 32, 32, 1) (3360, 32, 32, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(20,20))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (13440, 29)
# (3360, 29)

# %%
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input,Conv1D,Flatten,BatchNormalization,SpatialDropout1D, MaxPooling1D,Dense,GlobalMaxPooling1D,Embedding
class attention(layers.Layer):
    def _init_(self,**kwargs):
        super(attention,self)._init_(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %%
model = Sequential([
    
    
    LSTM(256, return_sequences=True, dropout=0.25, input_shape=(32,32)),
    Dense(256, activation='relu'),
    
    LSTM(128, return_sequences=True, dropout=0.5),
    Dense(128, activation='relu'),
    
    LSTM(64, return_sequences=True, dropout=0.5),
    Dense(64, activation='relu'),
    
    LSTM(32, return_sequences=True, dropout=0.5),
    Dense(32, activation='relu'),
    
    attention(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(total_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32, 256)           295936
#
#  dense (Dense)               (None, 32, 256)           65792
#
#  lstm_1 (LSTM)               (None, 32, 128)           197120
#
#  dense_1 (Dense)             (None, 32, 128)           16512
#
#  lstm_2 (LSTM)               (None, 32, 64)            49408
#
#  dense_2 (Dense)             (None, 32, 64)            4160
#
#  lstm_3 (LSTM)               (None, 32, 32)            12416
#
#  dense_3 (Dense)             (None, 32, 32)            1056
#
#  attention (attention)       (None, 32)                64
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 128)               4224
#
#  dense_5 (Dense)             (None, 256)               33024
#
#  dense_6 (Dense)             (None, 29)                7453
#
# =================================================================
# Total params: 687,165
# Trainable params: 687,165
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 105/105 [==============================] - 15s 31ms/step - loss: 2.9562 - accuracy: 0.1042 - val_loss: 2.4698 - val_accuracy: 0.1955
# Epoch 2/150
# 105/105 [==============================] - 2s 16ms/step - loss: 2.3357 - accuracy: 0.2127 - val_loss: 2.0343 - val_accuracy: 0.2693
# Epoch 3/150
# 105/105 [==============================] - 2s 17ms/step - loss: 2.0128 - accuracy: 0.2812 - val_loss: 1.7076 - val_accuracy: 0.3393
# Epoch 4/150
# 105/105 [==============================] - 2s 17ms/step - loss: 1.7453 - accuracy: 0.3592 - val_loss: 1.5260 - val_accuracy: 0.4247
# Epoch 5/150
# 105/105 [==============================] - 2s 17ms/step - loss: 1.5352 - accuracy: 0.4291 - val_loss: 1.3536 - val_accuracy: 0.4509
# Epoch 6/150
# 105/105 [==============================] - 2s 17ms/step - loss: 1.3852 - accuracy: 0.4734 - val_loss: 1.1907 - val_accuracy: 0.5467
# Epoch 7/150
# 105/105 [==============================] - 2s 17ms/step - loss: 1.2496 - accuracy: 0.5304 - val_loss: 1.0553 - val_accuracy: 0.6000
# Epoch 8/150
# 105/105 [==============================] - 2s 17ms/step - loss: 1.1276 - accuracy: 0.5810 - val_loss: 0.9153 - val_accuracy: 0.6500
# Epoch 9/150
# 105/105 [==============================] - 2s 18ms/step - loss: 1.0281 - accuracy: 0.6125 - val_loss: 0.8589 - val_accuracy: 0.6810
# Epoch 10/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.9295 - accuracy: 0.6549 - val_loss: 0.8284 - val_accuracy: 0.7006
# Epoch 11/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.8604 - accuracy: 0.6805 - val_loss: 0.7307 - val_accuracy: 0.7247
# Epoch 12/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.8200 - accuracy: 0.6989 - val_loss: 0.6704 - val_accuracy: 0.7542
# Epoch 13/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.7375 - accuracy: 0.7335 - val_loss: 0.7206 - val_accuracy: 0.7491
# Epoch 14/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.6970 - accuracy: 0.7507 - val_loss: 0.6197 - val_accuracy: 0.7920
# Epoch 15/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.6573 - accuracy: 0.7652 - val_loss: 0.5210 - val_accuracy: 0.8241
# Epoch 16/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.6191 - accuracy: 0.7829 - val_loss: 0.5607 - val_accuracy: 0.8104
# Epoch 17/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.5676 - accuracy: 0.8019 - val_loss: 0.4869 - val_accuracy: 0.8411
# Epoch 18/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5659 - accuracy: 0.8015 - val_loss: 0.4545 - val_accuracy: 0.8479
# Epoch 19/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5171 - accuracy: 0.8207 - val_loss: 0.4355 - val_accuracy: 0.8592
# Epoch 20/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4826 - accuracy: 0.8328 - val_loss: 0.4087 - val_accuracy: 0.8732
# Epoch 21/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4484 - accuracy: 0.8458 - val_loss: 0.3911 - val_accuracy: 0.8756
# Epoch 22/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4356 - accuracy: 0.8556 - val_loss: 0.4520 - val_accuracy: 0.8625
# Epoch 23/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4167 - accuracy: 0.8570 - val_loss: 0.3779 - val_accuracy: 0.8744
# Epoch 24/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4030 - accuracy: 0.8655 - val_loss: 0.3716 - val_accuracy: 0.8801
# Epoch 25/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.3801 - accuracy: 0.8727 - val_loss: 0.3279 - val_accuracy: 0.8976
# Epoch 26/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.3418 - accuracy: 0.8868 - val_loss: 0.3748 - val_accuracy: 0.8860
# Epoch 27/150
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3476 - accuracy: 0.8839 - val_loss: 0.3493 - val_accuracy: 0.8893
# Epoch 28/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.3356 - accuracy: 0.8926 - val_loss: 0.3569 - val_accuracy: 0.8932
# Epoch 29/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.3073 - accuracy: 0.9003 - val_loss: 0.3471 - val_accuracy: 0.8979
# Epoch 30/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.3132 - accuracy: 0.8982 - val_loss: 0.2860 - val_accuracy: 0.9104
# Epoch 31/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2977 - accuracy: 0.9030 - val_loss: 0.3026 - val_accuracy: 0.9086
# Epoch 32/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2852 - accuracy: 0.9059 - val_loss: 0.3044 - val_accuracy: 0.9146
# Epoch 33/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2703 - accuracy: 0.9102 - val_loss: 0.3229 - val_accuracy: 0.9060
# Epoch 34/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2665 - accuracy: 0.9129 - val_loss: 0.3134 - val_accuracy: 0.9143
# Epoch 35/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2466 - accuracy: 0.9189 - val_loss: 0.2753 - val_accuracy: 0.9176
# Epoch 36/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2430 - accuracy: 0.9200 - val_loss: 0.2863 - val_accuracy: 0.9235
# Epoch 37/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2439 - accuracy: 0.9240 - val_loss: 0.3043 - val_accuracy: 0.9134
# Epoch 38/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.2364 - accuracy: 0.9263 - val_loss: 0.2634 - val_accuracy: 0.9253
# Epoch 39/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.2198 - accuracy: 0.9304 - val_loss: 0.2661 - val_accuracy: 0.9244
# Epoch 40/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2244 - accuracy: 0.9278 - val_loss: 0.2633 - val_accuracy: 0.9268
# Epoch 41/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2241 - accuracy: 0.9289 - val_loss: 0.2618 - val_accuracy: 0.9277
# Epoch 42/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2225 - accuracy: 0.9279 - val_loss: 0.2597 - val_accuracy: 0.9292
# Epoch 43/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2052 - accuracy: 0.9331 - val_loss: 0.2673 - val_accuracy: 0.9298
# Epoch 44/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2166 - accuracy: 0.9322 - val_loss: 0.2537 - val_accuracy: 0.9283
# Epoch 45/150
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2098 - accuracy: 0.9339 - val_loss: 0.2477 - val_accuracy: 0.9304
# Epoch 46/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2062 - accuracy: 0.9341 - val_loss: 0.2548 - val_accuracy: 0.9304
# Epoch 47/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1831 - accuracy: 0.9411 - val_loss: 0.2616 - val_accuracy: 0.9256
# Epoch 48/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1817 - accuracy: 0.9439 - val_loss: 0.2878 - val_accuracy: 0.9256
# Epoch 49/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1769 - accuracy: 0.9447 - val_loss: 0.2765 - val_accuracy: 0.9238
# Epoch 50/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1853 - accuracy: 0.9433 - val_loss: 0.2298 - val_accuracy: 0.9363
# Epoch 51/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1831 - accuracy: 0.9420 - val_loss: 0.2485 - val_accuracy: 0.9318
# Epoch 52/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1748 - accuracy: 0.9445 - val_loss: 0.2778 - val_accuracy: 0.9244
# Epoch 53/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1736 - accuracy: 0.9460 - val_loss: 0.2611 - val_accuracy: 0.9283
# Epoch 54/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1744 - accuracy: 0.9455 - val_loss: 0.2694 - val_accuracy: 0.9304
# Epoch 55/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1631 - accuracy: 0.9493 - val_loss: 0.2282 - val_accuracy: 0.9405
# Epoch 56/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1548 - accuracy: 0.9556 - val_loss: 0.2444 - val_accuracy: 0.9443
# Epoch 57/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1540 - accuracy: 0.9510 - val_loss: 0.2543 - val_accuracy: 0.9381
# Epoch 58/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1559 - accuracy: 0.9525 - val_loss: 0.2383 - val_accuracy: 0.9381
# Epoch 59/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1571 - accuracy: 0.9511 - val_loss: 0.2667 - val_accuracy: 0.9336
# Epoch 60/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1549 - accuracy: 0.9531 - val_loss: 0.2599 - val_accuracy: 0.9345
# Epoch 61/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1353 - accuracy: 0.9589 - val_loss: 0.2469 - val_accuracy: 0.9366
# Epoch 62/150
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1477 - accuracy: 0.9530 - val_loss: 0.2707 - val_accuracy: 0.9274
# Epoch 63/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1516 - accuracy: 0.9519 - val_loss: 0.2251 - val_accuracy: 0.9411
# Epoch 64/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1474 - accuracy: 0.9548 - val_loss: 0.2684 - val_accuracy: 0.9342
# Epoch 65/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1495 - accuracy: 0.9543 - val_loss: 0.2296 - val_accuracy: 0.9372
# Epoch 66/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1479 - accuracy: 0.9540 - val_loss: 0.2484 - val_accuracy: 0.9366
# Epoch 67/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1401 - accuracy: 0.9577 - val_loss: 0.2549 - val_accuracy: 0.9366
# Epoch 68/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1278 - accuracy: 0.9603 - val_loss: 0.2553 - val_accuracy: 0.9390
# Epoch 69/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1285 - accuracy: 0.9618 - val_loss: 0.2241 - val_accuracy: 0.9440
# Epoch 70/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1185 - accuracy: 0.9635 - val_loss: 0.2439 - val_accuracy: 0.9449
# Epoch 71/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1324 - accuracy: 0.9576 - val_loss: 0.2414 - val_accuracy: 0.9348
# Epoch 72/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1352 - accuracy: 0.9570 - val_loss: 0.2380 - val_accuracy: 0.9390
# Epoch 73/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1365 - accuracy: 0.9579 - val_loss: 0.2522 - val_accuracy: 0.9360
# Epoch 74/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1281 - accuracy: 0.9621 - val_loss: 0.2745 - val_accuracy: 0.9366
# Epoch 75/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1174 - accuracy: 0.9627 - val_loss: 0.2402 - val_accuracy: 0.9417
# Epoch 76/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1154 - accuracy: 0.9632 - val_loss: 0.2422 - val_accuracy: 0.9414
# Epoch 77/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1221 - accuracy: 0.9619 - val_loss: 0.2554 - val_accuracy: 0.9402
# Epoch 78/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1030 - accuracy: 0.9682 - val_loss: 0.2480 - val_accuracy: 0.9408
# Epoch 79/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1132 - accuracy: 0.9656 - val_loss: 0.2455 - val_accuracy: 0.9396
# Epoch 80/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1176 - accuracy: 0.9653 - val_loss: 0.2466 - val_accuracy: 0.9399
# Epoch 81/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1090 - accuracy: 0.9673 - val_loss: 0.2312 - val_accuracy: 0.9429
# Epoch 82/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1300 - accuracy: 0.9606 - val_loss: 0.2474 - val_accuracy: 0.9393
# Epoch 83/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1110 - accuracy: 0.9641 - val_loss: 0.2236 - val_accuracy: 0.9455
# Epoch 84/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1069 - accuracy: 0.9675 - val_loss: 0.2289 - val_accuracy: 0.9432
# Epoch 85/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1127 - accuracy: 0.9670 - val_loss: 0.2568 - val_accuracy: 0.9429
# Epoch 86/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1160 - accuracy: 0.9656 - val_loss: 0.2540 - val_accuracy: 0.9438
# Epoch 87/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1163 - accuracy: 0.9644 - val_loss: 0.2653 - val_accuracy: 0.9423
# Epoch 88/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0995 - accuracy: 0.9715 - val_loss: 0.2555 - val_accuracy: 0.9423
# Epoch 89/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1098 - accuracy: 0.9667 - val_loss: 0.2401 - val_accuracy: 0.9423
# Epoch 90/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0983 - accuracy: 0.9728 - val_loss: 0.2392 - val_accuracy: 0.9443
# Epoch 91/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1031 - accuracy: 0.9693 - val_loss: 0.2304 - val_accuracy: 0.9461
# Epoch 92/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1030 - accuracy: 0.9690 - val_loss: 0.2337 - val_accuracy: 0.9455
# Epoch 93/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1017 - accuracy: 0.9687 - val_loss: 0.2820 - val_accuracy: 0.9321
# Epoch 94/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1046 - accuracy: 0.9690 - val_loss: 0.2464 - val_accuracy: 0.9423
# Epoch 95/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1084 - accuracy: 0.9676 - val_loss: 0.2374 - val_accuracy: 0.9414
# Epoch 96/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1000 - accuracy: 0.9704 - val_loss: 0.2413 - val_accuracy: 0.9467
# Epoch 97/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1117 - accuracy: 0.9670 - val_loss: 0.2370 - val_accuracy: 0.9438
# Epoch 98/150
# 105/105 [==============================] - 2s 18ms/step - loss: 0.0942 - accuracy: 0.9722 - val_loss: 0.2316 - val_accuracy: 0.9473
# Epoch 99/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1072 - accuracy: 0.9666 - val_loss: 0.2358 - val_accuracy: 0.9467
# Epoch 100/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0960 - accuracy: 0.9717 - val_loss: 0.2329 - val_accuracy: 0.9446
# Epoch 101/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0870 - accuracy: 0.9746 - val_loss: 0.2342 - val_accuracy: 0.9467
# Epoch 102/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0951 - accuracy: 0.9728 - val_loss: 0.2296 - val_accuracy: 0.9467
# Epoch 103/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1078 - accuracy: 0.9696 - val_loss: 0.2990 - val_accuracy: 0.9378
# Epoch 104/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1019 - accuracy: 0.9696 - val_loss: 0.2331 - val_accuracy: 0.9485
# Epoch 105/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0901 - accuracy: 0.9751 - val_loss: 0.2159 - val_accuracy: 0.9458
# Epoch 106/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0787 - accuracy: 0.9764 - val_loss: 0.2690 - val_accuracy: 0.9426
# Epoch 107/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0937 - accuracy: 0.9720 - val_loss: 0.2392 - val_accuracy: 0.9461
# Epoch 108/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0969 - accuracy: 0.9714 - val_loss: 0.2470 - val_accuracy: 0.9464
# Epoch 109/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0847 - accuracy: 0.9757 - val_loss: 0.2384 - val_accuracy: 0.9521
# Epoch 110/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0856 - accuracy: 0.9738 - val_loss: 0.2505 - val_accuracy: 0.9485
# Epoch 111/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0897 - accuracy: 0.9740 - val_loss: 0.2544 - val_accuracy: 0.9479
# Epoch 112/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0897 - accuracy: 0.9746 - val_loss: 0.2632 - val_accuracy: 0.9455
# Epoch 113/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0857 - accuracy: 0.9749 - val_loss: 0.2445 - val_accuracy: 0.9452
# Epoch 114/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0830 - accuracy: 0.9746 - val_loss: 0.2470 - val_accuracy: 0.9458
# Epoch 115/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0896 - accuracy: 0.9735 - val_loss: 0.2290 - val_accuracy: 0.9482
# Epoch 116/150
# 105/105 [==============================] - 2s 18ms/step - loss: 0.0869 - accuracy: 0.9739 - val_loss: 0.2473 - val_accuracy: 0.9467
# Epoch 117/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0842 - accuracy: 0.9761 - val_loss: 0.2632 - val_accuracy: 0.9458
# Epoch 118/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0769 - accuracy: 0.9771 - val_loss: 0.2531 - val_accuracy: 0.9461
# Epoch 119/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0807 - accuracy: 0.9763 - val_loss: 0.2461 - val_accuracy: 0.9515
# Epoch 120/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0793 - accuracy: 0.9775 - val_loss: 0.2400 - val_accuracy: 0.9485
# Epoch 121/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0772 - accuracy: 0.9765 - val_loss: 0.2423 - val_accuracy: 0.9455
# Epoch 122/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0837 - accuracy: 0.9764 - val_loss: 0.2472 - val_accuracy: 0.9435
# Epoch 123/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0712 - accuracy: 0.9791 - val_loss: 0.2673 - val_accuracy: 0.9461
# Epoch 124/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0878 - accuracy: 0.9738 - val_loss: 0.2840 - val_accuracy: 0.9420
# Epoch 125/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0884 - accuracy: 0.9749 - val_loss: 0.2362 - val_accuracy: 0.9497
# Epoch 126/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0712 - accuracy: 0.9775 - val_loss: 0.2682 - val_accuracy: 0.9455
# Epoch 127/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0714 - accuracy: 0.9789 - val_loss: 0.2658 - val_accuracy: 0.9461
# Epoch 128/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0790 - accuracy: 0.9770 - val_loss: 0.2551 - val_accuracy: 0.9458
# Epoch 129/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0739 - accuracy: 0.9798 - val_loss: 0.2654 - val_accuracy: 0.9443
# Epoch 130/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0763 - accuracy: 0.9757 - val_loss: 0.2408 - val_accuracy: 0.9464
# Epoch 131/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0760 - accuracy: 0.9771 - val_loss: 0.2399 - val_accuracy: 0.9473
# Epoch 132/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0739 - accuracy: 0.9776 - val_loss: 0.2691 - val_accuracy: 0.9455
# Epoch 133/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0721 - accuracy: 0.9790 - val_loss: 0.2497 - val_accuracy: 0.9470
# Epoch 134/150
# 105/105 [==============================] - 2s 18ms/step - loss: 0.0641 - accuracy: 0.9795 - val_loss: 0.2843 - val_accuracy: 0.9402
# Epoch 135/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0690 - accuracy: 0.9810 - val_loss: 0.2318 - val_accuracy: 0.9479
# Epoch 136/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0698 - accuracy: 0.9801 - val_loss: 0.2788 - val_accuracy: 0.9393
# Epoch 137/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0738 - accuracy: 0.9779 - val_loss: 0.2594 - val_accuracy: 0.9446
# Epoch 138/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0715 - accuracy: 0.9807 - val_loss: 0.2781 - val_accuracy: 0.9405
# Epoch 139/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0737 - accuracy: 0.9790 - val_loss: 0.2239 - val_accuracy: 0.9515
# Epoch 140/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0680 - accuracy: 0.9791 - val_loss: 0.2446 - val_accuracy: 0.9494
# Epoch 141/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0732 - accuracy: 0.9800 - val_loss: 0.2417 - val_accuracy: 0.9470
# Epoch 142/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0622 - accuracy: 0.9806 - val_loss: 0.2463 - val_accuracy: 0.9515
# Epoch 143/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0644 - accuracy: 0.9815 - val_loss: 0.2606 - val_accuracy: 0.9497
# Epoch 144/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0637 - accuracy: 0.9815 - val_loss: 0.2185 - val_accuracy: 0.9497
# Epoch 145/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0754 - accuracy: 0.9781 - val_loss: 0.2432 - val_accuracy: 0.9512
# Epoch 146/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0641 - accuracy: 0.9805 - val_loss: 0.2363 - val_accuracy: 0.9479
# Epoch 147/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0619 - accuracy: 0.9826 - val_loss: 0.2259 - val_accuracy: 0.9563
# Epoch 148/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0617 - accuracy: 0.9827 - val_loss: 0.2427 - val_accuracy: 0.9500
# Epoch 149/150
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0653 - accuracy: 0.9816 - val_loss: 0.2565 - val_accuracy: 0.9446
# Epoch 150/150
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0668 - accuracy: 0.9812 - val_loss: 0.2309 - val_accuracy: 0.9491

# %%
y_held_pred=model.predict(x_test)
# Out:
# 105/105 [==============================] - 2s 6ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (3360,)
# (3360,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 105/105 [==============================] - 1s 8ms/step - loss: 0.2309 - accuracy: 0.9491
# [0.23094555735588074, 0.9491071701049805]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 105/105 - 1s - loss: 0.2309 - accuracy: 0.9491 - 755ms/epoch - 7ms/step
# [0.23094555735588074, 0.9491071701049805]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 420/420 [==============================] - 2s 5ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (13440,)
# (13440,)
# 420/420 - 3s - loss: 0.0092 - accuracy: 0.9972 - 3s/epoch - 7ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 105/105 [==============================] - 1s 5ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.2, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((28,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(28):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 28))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('LSTM' , y_pred)
# Out:
# LSTM Accuracy: 94.91%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.99       120
#            2       1.00      0.96      0.98       120
#            3       0.94      0.88      0.91       120
#            4       0.90      0.97      0.93       120
#            5       0.93      0.93      0.93       120
#            6       0.91      0.92      0.91       120
#            7       0.97      0.93      0.95       120
#            8       0.91      0.97      0.94       120
#            9       0.94      0.85      0.89       120
#           10       0.92      0.96      0.94       120
#           11       0.92      0.91      0.91       120
#           12       0.99      0.95      0.97       120
#           13       0.99      0.97      0.98       120
#           14       0.92      0.98      0.95       120
#           15       0.96      0.94      0.95       120
#           16       0.94      0.97      0.95       120
#           17       0.95      0.96      0.95       120
#           18       0.90      0.93      0.92       120
#           19       0.95      0.95      0.95       120
#           20       0.93      0.96      0.94       120
#           21       0.96      0.92      0.94       120
#           22       0.99      0.98      0.99       120
#           23       0.99      0.99      0.99       120
#           24       0.95      0.99      0.97       120
#           25       0.96      0.96      0.96       120
#           26       0.95      0.95      0.95       120
#           27       0.96      0.93      0.94       120
#           28       0.97      0.97      0.97       120
#
#     accuracy                           0.95      3360
#    macro avg       0.95      0.95      0.95      3360
# weighted avg       0.95      0.95      0.95      3360

# %% [markdown]
# ###
