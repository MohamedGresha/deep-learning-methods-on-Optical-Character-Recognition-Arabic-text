# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU,Bidirectional,Embedding
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
x_train = pd.read_csv(r"/kaggle/input/ahcd1/csvTrainImages 13440x1024.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/ahcd1/csvTrainLabel 13440x1.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/ahcd1/csvTestImages 3360x1024.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/ahcd1/csvTestLabel 3360x1.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
x_train = x_train.reshape(-1,32,32,1)
x_test = x_test.reshape(-1,32,32,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (13440, 32, 32, 1) (3360, 32, 32, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(5,5))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (13440, 29)
# (3360, 29)

# %%
from tensorflow.keras.layers import InputLayer,BatchNormalization, Reshape,Embedding

model = Sequential([
    
    InputLayer(input_shape=(32,32)),
   # Embedding(input_dim=200, output_dim=32, input_length=50),
    #Dense(256, activation='sigmoid'),
    #BatchNormalization(),
    Bidirectional(LSTM(256, return_sequences=True, dropout=0.25)),
    Dense(256, activation='relu'),
    
    Bidirectional(LSTM(128, return_sequences=True, dropout=0.5)),
    Dense(128, activation='relu'),
    
    Bidirectional(LSTM(64, return_sequences=True, dropout=0.5)),
    Dense(64, activation='relu'),
    
    Bidirectional(LSTM(32, return_sequences=True, dropout=0.5)),
    Dense(32, activation='relu'),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(total_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 32, 512)          591872
#  l)
#
#  dense (Dense)               (None, 32, 256)           131328
#
#  bidirectional_1 (Bidirectio  (None, 32, 256)          394240
#  nal)
#
#  dense_1 (Dense)             (None, 32, 128)           32896
#
#  bidirectional_2 (Bidirectio  (None, 32, 128)          98816
#  nal)
#
#  dense_2 (Dense)             (None, 32, 64)            8256
#
#  bidirectional_3 (Bidirectio  (None, 32, 64)           24832
#  nal)
#
#  dense_3 (Dense)             (None, 32, 32)            2080
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense_4 (Dense)             (None, 128)               131200
#
#  dense_5 (Dense)             (None, 256)               33024
#
#  dense_6 (Dense)             (None, 29)                7453
#
# =================================================================
# Total params: 1,455,997
# Trainable params: 1,455,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 105/105 [==============================] - 20s 57ms/step - loss: 2.7515 - accuracy: 0.1469 - val_loss: 2.0635 - val_accuracy: 0.2943
# Epoch 2/150
# 105/105 [==============================] - 3s 32ms/step - loss: 1.8585 - accuracy: 0.3530 - val_loss: 1.3888 - val_accuracy: 0.4815
# Epoch 3/150
# 105/105 [==============================] - 3s 32ms/step - loss: 1.3902 - accuracy: 0.4909 - val_loss: 1.1239 - val_accuracy: 0.5878
# Epoch 4/150
# 105/105 [==============================] - 3s 31ms/step - loss: 1.1455 - accuracy: 0.5799 - val_loss: 0.9511 - val_accuracy: 0.6524
# Epoch 5/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.9732 - accuracy: 0.6438 - val_loss: 0.9297 - val_accuracy: 0.6682
# Epoch 6/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.8710 - accuracy: 0.6790 - val_loss: 0.7394 - val_accuracy: 0.7315
# Epoch 7/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.7493 - accuracy: 0.7269 - val_loss: 0.7001 - val_accuracy: 0.7503
# Epoch 8/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.6848 - accuracy: 0.7507 - val_loss: 0.6315 - val_accuracy: 0.7810
# Epoch 9/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.6302 - accuracy: 0.7723 - val_loss: 0.5417 - val_accuracy: 0.8092
# Epoch 10/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.5775 - accuracy: 0.7961 - val_loss: 0.5266 - val_accuracy: 0.8182
# Epoch 11/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.5439 - accuracy: 0.8078 - val_loss: 0.4602 - val_accuracy: 0.8509
# Epoch 12/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.4976 - accuracy: 0.8287 - val_loss: 0.4621 - val_accuracy: 0.8426
# Epoch 13/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.4672 - accuracy: 0.8355 - val_loss: 0.4193 - val_accuracy: 0.8539
# Epoch 14/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.4314 - accuracy: 0.8456 - val_loss: 0.3866 - val_accuracy: 0.8687
# Epoch 15/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.4117 - accuracy: 0.8549 - val_loss: 0.3879 - val_accuracy: 0.8741
# Epoch 16/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.3826 - accuracy: 0.8665 - val_loss: 0.3760 - val_accuracy: 0.8845
# Epoch 17/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.3448 - accuracy: 0.8802 - val_loss: 0.3692 - val_accuracy: 0.8887
# Epoch 18/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.3580 - accuracy: 0.8760 - val_loss: 0.3645 - val_accuracy: 0.8848
# Epoch 19/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.3395 - accuracy: 0.8835 - val_loss: 0.3742 - val_accuracy: 0.8842
# Epoch 20/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.3168 - accuracy: 0.8932 - val_loss: 0.3558 - val_accuracy: 0.8863
# Epoch 21/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.3027 - accuracy: 0.8971 - val_loss: 0.3311 - val_accuracy: 0.8964
# Epoch 22/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2780 - accuracy: 0.9057 - val_loss: 0.3487 - val_accuracy: 0.9015
# Epoch 23/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2728 - accuracy: 0.9100 - val_loss: 0.3269 - val_accuracy: 0.8967
# Epoch 24/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2529 - accuracy: 0.9155 - val_loss: 0.3360 - val_accuracy: 0.9071
# Epoch 25/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2570 - accuracy: 0.9130 - val_loss: 0.3045 - val_accuracy: 0.9125
# Epoch 26/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2474 - accuracy: 0.9158 - val_loss: 0.3334 - val_accuracy: 0.9009
# Epoch 27/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2479 - accuracy: 0.9170 - val_loss: 0.3709 - val_accuracy: 0.8935
# Epoch 28/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2342 - accuracy: 0.9215 - val_loss: 0.3181 - val_accuracy: 0.9107
# Epoch 29/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.2247 - accuracy: 0.9262 - val_loss: 0.2906 - val_accuracy: 0.9193
# Epoch 30/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.2057 - accuracy: 0.9312 - val_loss: 0.2855 - val_accuracy: 0.9146
# Epoch 31/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.2090 - accuracy: 0.9311 - val_loss: 0.3050 - val_accuracy: 0.9185
# Epoch 32/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1992 - accuracy: 0.9325 - val_loss: 0.2746 - val_accuracy: 0.9247
# Epoch 33/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.2020 - accuracy: 0.9329 - val_loss: 0.2873 - val_accuracy: 0.9223
# Epoch 34/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1964 - accuracy: 0.9345 - val_loss: 0.2929 - val_accuracy: 0.9187
# Epoch 35/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1854 - accuracy: 0.9390 - val_loss: 0.2764 - val_accuracy: 0.9208
# Epoch 36/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1831 - accuracy: 0.9382 - val_loss: 0.2832 - val_accuracy: 0.9238
# Epoch 37/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1661 - accuracy: 0.9455 - val_loss: 0.2856 - val_accuracy: 0.9277
# Epoch 38/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1670 - accuracy: 0.9450 - val_loss: 0.2887 - val_accuracy: 0.9235
# Epoch 39/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1680 - accuracy: 0.9447 - val_loss: 0.3150 - val_accuracy: 0.9170
# Epoch 40/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1652 - accuracy: 0.9458 - val_loss: 0.2383 - val_accuracy: 0.9324
# Epoch 41/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1485 - accuracy: 0.9504 - val_loss: 0.2936 - val_accuracy: 0.9256
# Epoch 42/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1532 - accuracy: 0.9497 - val_loss: 0.2712 - val_accuracy: 0.9274
# Epoch 43/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1527 - accuracy: 0.9505 - val_loss: 0.2846 - val_accuracy: 0.9301
# Epoch 44/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1487 - accuracy: 0.9527 - val_loss: 0.2348 - val_accuracy: 0.9372
# Epoch 45/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1304 - accuracy: 0.9553 - val_loss: 0.2858 - val_accuracy: 0.9366
# Epoch 46/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1390 - accuracy: 0.9544 - val_loss: 0.2686 - val_accuracy: 0.9354
# Epoch 47/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1354 - accuracy: 0.9564 - val_loss: 0.2766 - val_accuracy: 0.9315
# Epoch 48/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1292 - accuracy: 0.9574 - val_loss: 0.2760 - val_accuracy: 0.9310
# Epoch 49/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1438 - accuracy: 0.9538 - val_loss: 0.2662 - val_accuracy: 0.9339
# Epoch 50/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1420 - accuracy: 0.9545 - val_loss: 0.2589 - val_accuracy: 0.9307
# Epoch 51/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1287 - accuracy: 0.9607 - val_loss: 0.2471 - val_accuracy: 0.9336
# Epoch 52/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1214 - accuracy: 0.9596 - val_loss: 0.3004 - val_accuracy: 0.9277
# Epoch 53/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1221 - accuracy: 0.9603 - val_loss: 0.2546 - val_accuracy: 0.9360
# Epoch 54/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1167 - accuracy: 0.9626 - val_loss: 0.2638 - val_accuracy: 0.9423
# Epoch 55/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1212 - accuracy: 0.9615 - val_loss: 0.2615 - val_accuracy: 0.9351
# Epoch 56/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1201 - accuracy: 0.9617 - val_loss: 0.2717 - val_accuracy: 0.9345
# Epoch 57/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1200 - accuracy: 0.9618 - val_loss: 0.2648 - val_accuracy: 0.9292
# Epoch 58/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1179 - accuracy: 0.9629 - val_loss: 0.2187 - val_accuracy: 0.9414
# Epoch 59/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1021 - accuracy: 0.9660 - val_loss: 0.2469 - val_accuracy: 0.9399
# Epoch 60/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1161 - accuracy: 0.9628 - val_loss: 0.2242 - val_accuracy: 0.9458
# Epoch 61/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1059 - accuracy: 0.9649 - val_loss: 0.2416 - val_accuracy: 0.9417
# Epoch 62/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0982 - accuracy: 0.9678 - val_loss: 0.2826 - val_accuracy: 0.9372
# Epoch 63/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1004 - accuracy: 0.9665 - val_loss: 0.2489 - val_accuracy: 0.9378
# Epoch 64/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0995 - accuracy: 0.9678 - val_loss: 0.2849 - val_accuracy: 0.9405
# Epoch 65/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.1057 - accuracy: 0.9663 - val_loss: 0.2411 - val_accuracy: 0.9449
# Epoch 66/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0934 - accuracy: 0.9703 - val_loss: 0.2613 - val_accuracy: 0.9423
# Epoch 67/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0984 - accuracy: 0.9693 - val_loss: 0.2618 - val_accuracy: 0.9360
# Epoch 68/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0938 - accuracy: 0.9705 - val_loss: 0.2879 - val_accuracy: 0.9354
# Epoch 69/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0987 - accuracy: 0.9689 - val_loss: 0.2456 - val_accuracy: 0.9449
# Epoch 70/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0871 - accuracy: 0.9720 - val_loss: 0.2246 - val_accuracy: 0.9479
# Epoch 71/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0892 - accuracy: 0.9719 - val_loss: 0.2557 - val_accuracy: 0.9393
# Epoch 72/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1043 - accuracy: 0.9686 - val_loss: 0.2419 - val_accuracy: 0.9452
# Epoch 73/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0964 - accuracy: 0.9712 - val_loss: 0.2330 - val_accuracy: 0.9440
# Epoch 74/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0865 - accuracy: 0.9736 - val_loss: 0.2408 - val_accuracy: 0.9458
# Epoch 75/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0776 - accuracy: 0.9761 - val_loss: 0.2990 - val_accuracy: 0.9372
# Epoch 76/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0860 - accuracy: 0.9736 - val_loss: 0.2145 - val_accuracy: 0.9527
# Epoch 77/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0826 - accuracy: 0.9734 - val_loss: 0.2942 - val_accuracy: 0.9423
# Epoch 78/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.1056 - accuracy: 0.9685 - val_loss: 0.2286 - val_accuracy: 0.9503
# Epoch 79/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0740 - accuracy: 0.9772 - val_loss: 0.2488 - val_accuracy: 0.9432
# Epoch 80/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0767 - accuracy: 0.9762 - val_loss: 0.3061 - val_accuracy: 0.9339
# Epoch 81/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0891 - accuracy: 0.9728 - val_loss: 0.2520 - val_accuracy: 0.9390
# Epoch 82/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0784 - accuracy: 0.9744 - val_loss: 0.2799 - val_accuracy: 0.9432
# Epoch 83/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0852 - accuracy: 0.9741 - val_loss: 0.2961 - val_accuracy: 0.9423
# Epoch 84/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0856 - accuracy: 0.9742 - val_loss: 0.2646 - val_accuracy: 0.9458
# Epoch 85/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0760 - accuracy: 0.9768 - val_loss: 0.2640 - val_accuracy: 0.9429
# Epoch 86/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0878 - accuracy: 0.9714 - val_loss: 0.2769 - val_accuracy: 0.9443
# Epoch 87/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0764 - accuracy: 0.9754 - val_loss: 0.2819 - val_accuracy: 0.9452
# Epoch 88/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0790 - accuracy: 0.9746 - val_loss: 0.2701 - val_accuracy: 0.9402
# Epoch 89/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0721 - accuracy: 0.9769 - val_loss: 0.2812 - val_accuracy: 0.9426
# Epoch 90/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0717 - accuracy: 0.9778 - val_loss: 0.2897 - val_accuracy: 0.9435
# Epoch 91/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0768 - accuracy: 0.9770 - val_loss: 0.2489 - val_accuracy: 0.9491
# Epoch 92/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0679 - accuracy: 0.9792 - val_loss: 0.2657 - val_accuracy: 0.9426
# Epoch 93/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0797 - accuracy: 0.9757 - val_loss: 0.2859 - val_accuracy: 0.9435
# Epoch 94/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0772 - accuracy: 0.9753 - val_loss: 0.2300 - val_accuracy: 0.9512
# Epoch 95/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0683 - accuracy: 0.9785 - val_loss: 0.2265 - val_accuracy: 0.9542
# Epoch 96/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0752 - accuracy: 0.9776 - val_loss: 0.2360 - val_accuracy: 0.9476
# Epoch 97/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0707 - accuracy: 0.9782 - val_loss: 0.2316 - val_accuracy: 0.9521
# Epoch 98/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0710 - accuracy: 0.9789 - val_loss: 0.2392 - val_accuracy: 0.9530
# Epoch 99/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0661 - accuracy: 0.9805 - val_loss: 0.2143 - val_accuracy: 0.9515
# Epoch 100/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0547 - accuracy: 0.9830 - val_loss: 0.2439 - val_accuracy: 0.9476
# Epoch 101/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0627 - accuracy: 0.9803 - val_loss: 0.2379 - val_accuracy: 0.9485
# Epoch 102/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0654 - accuracy: 0.9795 - val_loss: 0.2456 - val_accuracy: 0.9482
# Epoch 103/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0567 - accuracy: 0.9818 - val_loss: 0.2594 - val_accuracy: 0.9494
# Epoch 104/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0639 - accuracy: 0.9807 - val_loss: 0.2649 - val_accuracy: 0.9426
# Epoch 105/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0687 - accuracy: 0.9801 - val_loss: 0.2730 - val_accuracy: 0.9426
# Epoch 106/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0647 - accuracy: 0.9800 - val_loss: 0.2453 - val_accuracy: 0.9509
# Epoch 107/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0651 - accuracy: 0.9798 - val_loss: 0.2302 - val_accuracy: 0.9485
# Epoch 108/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0485 - accuracy: 0.9839 - val_loss: 0.2586 - val_accuracy: 0.9455
# Epoch 109/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0572 - accuracy: 0.9833 - val_loss: 0.2744 - val_accuracy: 0.9473
# Epoch 110/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0614 - accuracy: 0.9816 - val_loss: 0.2202 - val_accuracy: 0.9533
# Epoch 111/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0680 - accuracy: 0.9799 - val_loss: 0.2634 - val_accuracy: 0.9455
# Epoch 112/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0682 - accuracy: 0.9795 - val_loss: 0.2292 - val_accuracy: 0.9551
# Epoch 113/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0659 - accuracy: 0.9801 - val_loss: 0.2350 - val_accuracy: 0.9497
# Epoch 114/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0560 - accuracy: 0.9844 - val_loss: 0.2176 - val_accuracy: 0.9533
# Epoch 115/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0496 - accuracy: 0.9856 - val_loss: 0.2501 - val_accuracy: 0.9500
# Epoch 116/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0494 - accuracy: 0.9848 - val_loss: 0.2512 - val_accuracy: 0.9500
# Epoch 117/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0503 - accuracy: 0.9859 - val_loss: 0.2985 - val_accuracy: 0.9494
# Epoch 118/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0638 - accuracy: 0.9802 - val_loss: 0.2782 - val_accuracy: 0.9449
# Epoch 119/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0662 - accuracy: 0.9806 - val_loss: 0.2699 - val_accuracy: 0.9455
# Epoch 120/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0620 - accuracy: 0.9799 - val_loss: 0.2675 - val_accuracy: 0.9470
# Epoch 121/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0651 - accuracy: 0.9811 - val_loss: 0.2324 - val_accuracy: 0.9506
# Epoch 122/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0552 - accuracy: 0.9834 - val_loss: 0.2428 - val_accuracy: 0.9521
# Epoch 123/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0512 - accuracy: 0.9836 - val_loss: 0.2512 - val_accuracy: 0.9512
# Epoch 124/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0477 - accuracy: 0.9856 - val_loss: 0.2406 - val_accuracy: 0.9476
# Epoch 125/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0473 - accuracy: 0.9847 - val_loss: 0.2588 - val_accuracy: 0.9491
# Epoch 126/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0629 - accuracy: 0.9815 - val_loss: 0.2659 - val_accuracy: 0.9420
# Epoch 127/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0654 - accuracy: 0.9815 - val_loss: 0.2770 - val_accuracy: 0.9488
# Epoch 128/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0522 - accuracy: 0.9842 - val_loss: 0.2460 - val_accuracy: 0.9551
# Epoch 129/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0587 - accuracy: 0.9839 - val_loss: 0.2405 - val_accuracy: 0.9491
# Epoch 130/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0571 - accuracy: 0.9825 - val_loss: 0.2536 - val_accuracy: 0.9488
# Epoch 131/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0504 - accuracy: 0.9858 - val_loss: 0.2614 - val_accuracy: 0.9509
# Epoch 132/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0523 - accuracy: 0.9847 - val_loss: 0.2517 - val_accuracy: 0.9524
# Epoch 133/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0484 - accuracy: 0.9850 - val_loss: 0.2522 - val_accuracy: 0.9533
# Epoch 134/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0495 - accuracy: 0.9847 - val_loss: 0.2768 - val_accuracy: 0.9524
# Epoch 135/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0508 - accuracy: 0.9849 - val_loss: 0.2581 - val_accuracy: 0.9515
# Epoch 136/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0495 - accuracy: 0.9844 - val_loss: 0.2444 - val_accuracy: 0.9497
# Epoch 137/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0511 - accuracy: 0.9845 - val_loss: 0.2671 - val_accuracy: 0.9440
# Epoch 138/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0434 - accuracy: 0.9868 - val_loss: 0.2465 - val_accuracy: 0.9536
# Epoch 139/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0469 - accuracy: 0.9855 - val_loss: 0.2385 - val_accuracy: 0.9494
# Epoch 140/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0453 - accuracy: 0.9861 - val_loss: 0.2642 - val_accuracy: 0.9518
# Epoch 141/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0472 - accuracy: 0.9860 - val_loss: 0.2493 - val_accuracy: 0.9488
# Epoch 142/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0601 - accuracy: 0.9818 - val_loss: 0.2658 - val_accuracy: 0.9464
# Epoch 143/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0520 - accuracy: 0.9844 - val_loss: 0.2402 - val_accuracy: 0.9515
# Epoch 144/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0460 - accuracy: 0.9856 - val_loss: 0.2614 - val_accuracy: 0.9503
# Epoch 145/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0464 - accuracy: 0.9868 - val_loss: 0.2736 - val_accuracy: 0.9500
# Epoch 146/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0616 - accuracy: 0.9830 - val_loss: 0.2345 - val_accuracy: 0.9479
# Epoch 147/150
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0429 - accuracy: 0.9872 - val_loss: 0.2421 - val_accuracy: 0.9479
# Epoch 148/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0374 - accuracy: 0.9888 - val_loss: 0.2492 - val_accuracy: 0.9536
# Epoch 149/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0517 - accuracy: 0.9844 - val_loss: 0.2823 - val_accuracy: 0.9446
# Epoch 150/150
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0474 - accuracy: 0.9871 - val_loss: 0.2531 - val_accuracy: 0.9488

# %%
y_held_pred=model.predict(x_test)
# Out:
# 105/105 [==============================] - 4s 9ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (3360,)
# (3360,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 105/105 [==============================] - 1s 11ms/step - loss: 0.2531 - accuracy: 0.9488
# [0.2530641257762909, 0.9488095045089722]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 105/105 - 1s - loss: 0.2531 - accuracy: 0.9488 - 1s/epoch - 10ms/step
# [0.2530641257762909, 0.9488095045089722]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 420/420 [==============================] - 4s 10ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (13440,)
# (13440,)
# 420/420 - 4s - loss: 0.0081 - accuracy: 0.9984 - 4s/epoch - 10ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 105/105 [==============================] - 1s 9ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.1, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((28,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(28):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 28))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('Bi-LSTM' , y_pred)
# Out:
# Bi-LSTM Accuracy: 94.88%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.99       120
#            2       0.99      0.97      0.98       120
#            3       0.94      0.82      0.87       120
#            4       0.88      0.95      0.92       120
#            5       0.94      0.93      0.93       120
#            6       0.93      0.93      0.93       120
#            7       0.94      0.93      0.94       120
#            8       0.91      0.97      0.94       120
#            9       0.95      0.87      0.91       120
#           10       0.92      0.95      0.93       120
#           11       0.96      0.88      0.92       120
#           12       0.97      0.96      0.97       120
#           13       0.96      1.00      0.98       120
#           14       0.93      0.97      0.95       120
#           15       0.98      0.94      0.96       120
#           16       0.94      0.99      0.96       120
#           17       0.99      0.95      0.97       120
#           18       0.93      0.97      0.95       120
#           19       0.98      0.94      0.96       120
#           20       0.85      0.97      0.91       120
#           21       0.96      0.89      0.92       120
#           22       0.97      0.97      0.97       120
#           23       0.98      0.99      0.98       120
#           24       0.98      1.00      0.99       120
#           25       0.96      0.92      0.94       120
#           26       0.96      0.97      0.97       120
#           27       0.92      0.96      0.94       120
#           28       0.98      0.97      0.98       120
#
#     accuracy                           0.95      3360
#    macro avg       0.95      0.95      0.95      3360
# weighted avg       0.95      0.95      0.95      3360
