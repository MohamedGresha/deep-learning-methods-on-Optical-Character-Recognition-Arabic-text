# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,LSTM,GRU
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score ,confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
x_train = pd.read_csv(r"/kaggle/input/Train_dataset 60kx784.csv",header=None)
y_train = pd.read_csv(r"/kaggle/input/Train_dataset (Label)60kx1.csv",header=None)

x_test = pd.read_csv(r"/kaggle/input/Test_dataset 10kx784.csv",header=None)
y_test = pd.read_csv(r"/kaggle/input/Test_dataset (Label) 10kx1.csv",header=None)

print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.iloc[:,:].values
x_test = x_test.iloc[:,:].values
y_train = y_train.iloc[:,:].values
y_test = y_test.iloc[:,:].values
print("x_train.shape =", x_train.shape, "\ny_train.shape =", 
      y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (60000, 784)
# y_train.shape = (60000, 1)
# x_test.shape = (10000, 784)
# y_test.shape = (10000, 1)

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
fig, ax = plt.subplots(6,4,figsize=(5,5))

for i in range(6):
    for j in range(4):
        ax[i,j].imshow(x_train[i])

# %%
total_classes = len(np.unique(y_train))+1
y_train = to_categorical(y_train,total_classes)
y_test = to_categorical(y_test, total_classes)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 11)
# (10000, 11)

# %%
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input,Conv1D,Flatten,BatchNormalization,SpatialDropout1D, MaxPooling1D,Dense,GlobalMaxPooling1D,Embedding
class attention(layers.Layer):
    def _init_(self,**kwargs):
        super(attention,self)._init_(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %%
from tensorflow.keras.layers import InputLayer,BatchNormalization, Reshape,BatchNormalization,ReLU,ZeroPadding2D,DepthwiseConv2D

model = Sequential([
    
     InputLayer(input_shape=(28,28,1)),
    
     Conv2D(64, (3,3), padding='valid', activation='relu',strides=1,
            kernel_initializer='HeNormal'),
     Conv2D(64, (3,3), padding='valid', activation='relu',strides=1),
     MaxPooling2D((2,2), strides=1),
     BatchNormalization(),

     Conv2D(128, (3,3), padding='valid', activation='relu',strides=1),
     MaxPooling2D((2,2), strides=1),
     BatchNormalization(),
    
     Conv2D(128, (3,3), padding='valid', activation='relu',strides=1),
     MaxPooling2D((2,2), strides=1),
     BatchNormalization(),
    
    Dropout(0.2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1024, activation='relu'),

    Dense(total_classes, activation='softmax')
    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)        0
#  D)
#
#  batch_normalization (Batch  (None, 23, 23, 64)        256
#  Normalization)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 20, 20, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 17, 17, 128)       512
#  chNormalization)
#
#  dropout (Dropout)           (None, 17, 17, 128)       0
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense (Dense)               (None, 512)               18940416
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  dense_2 (Dense)             (None, 11)                11275
#
# =================================================================
# Total params: 19737291 (75.29 MB)
# Trainable params: 19736651 (75.29 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,
                    #steps_per_epoch=len(x_train)//128,
                    batch_size=128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                   # validation_steps=50
                   )
# Out:
# Epoch 1/150
# 2023-12-07 14:37:58.340302: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 469/469 [==============================] - 22s 25ms/step - loss: 0.2166 - accuracy: 0.9744 - val_loss: 0.0885 - val_accuracy: 0.9818
# Epoch 2/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0419 - accuracy: 0.9915 - val_loss: 0.0990 - val_accuracy: 0.9860
# Epoch 3/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0346 - accuracy: 0.9925 - val_loss: 0.0842 - val_accuracy: 0.9821
# Epoch 4/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0225 - accuracy: 0.9948 - val_loss: 0.0580 - val_accuracy: 0.9886
# Epoch 5/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0192 - accuracy: 0.9953 - val_loss: 0.0858 - val_accuracy: 0.9854
# Epoch 6/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0416 - accuracy: 0.9917 - val_loss: 0.0955 - val_accuracy: 0.9861
# Epoch 7/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0219 - accuracy: 0.9951 - val_loss: 0.0628 - val_accuracy: 0.9897
# Epoch 8/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.0897 - val_accuracy: 0.9864
# Epoch 9/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0343 - accuracy: 0.9937 - val_loss: 0.0910 - val_accuracy: 0.9867
# Epoch 10/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.0982 - val_accuracy: 0.9860
# Epoch 11/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.0786 - val_accuracy: 0.9883
# Epoch 12/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.1077 - val_accuracy: 0.9829
# Epoch 13/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0411 - accuracy: 0.9935 - val_loss: 0.1560 - val_accuracy: 0.9814
# Epoch 14/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0178 - accuracy: 0.9962 - val_loss: 0.0635 - val_accuracy: 0.9919
# Epoch 15/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0077 - accuracy: 0.9982 - val_loss: 0.3175 - val_accuracy: 0.9782
# Epoch 16/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0196 - accuracy: 0.9963 - val_loss: 0.1119 - val_accuracy: 0.9876
# Epoch 17/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0970 - val_accuracy: 0.9897
# Epoch 18/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0127 - accuracy: 0.9973 - val_loss: 0.1687 - val_accuracy: 0.9871
# Epoch 19/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0089 - accuracy: 0.9980 - val_loss: 0.1721 - val_accuracy: 0.9861
# Epoch 20/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0130 - accuracy: 0.9976 - val_loss: 0.1475 - val_accuracy: 0.9866
# Epoch 21/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0085 - accuracy: 0.9982 - val_loss: 0.0999 - val_accuracy: 0.9903
# Epoch 22/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.1027 - val_accuracy: 0.9884
# Epoch 23/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.1185 - val_accuracy: 0.9873
# Epoch 24/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0302 - accuracy: 0.9959 - val_loss: 0.3509 - val_accuracy: 0.9872
# Epoch 25/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0101 - accuracy: 0.9982 - val_loss: 0.2893 - val_accuracy: 0.9889
# Epoch 26/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.2965 - val_accuracy: 0.9891
# Epoch 27/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.2276 - val_accuracy: 0.9902
# Epoch 28/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0090 - accuracy: 0.9989 - val_loss: 0.3064 - val_accuracy: 0.9865
# Epoch 29/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.4727 - val_accuracy: 0.9883
# Epoch 30/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0067 - accuracy: 0.9988 - val_loss: 0.4488 - val_accuracy: 0.9899
# Epoch 31/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.5248 - val_accuracy: 0.9869
# Epoch 32/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.6702 - val_accuracy: 0.9890
# Epoch 33/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.4996 - val_accuracy: 0.9903
# Epoch 34/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0071 - accuracy: 0.9992 - val_loss: 0.7512 - val_accuracy: 0.9831
# Epoch 35/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0103 - accuracy: 0.9985 - val_loss: 1.1397 - val_accuracy: 0.9900
# Epoch 36/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.9786 - val_accuracy: 0.9872
# Epoch 37/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.8429 - val_accuracy: 0.9903
# Epoch 38/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0114 - accuracy: 0.9984 - val_loss: 1.2522 - val_accuracy: 0.9896
# Epoch 39/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 1.4679 - val_accuracy: 0.9880
# Epoch 40/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 1.9705 - val_accuracy: 0.9888
# Epoch 41/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 1.3170 - val_accuracy: 0.9907
# Epoch 42/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 1.5977 - val_accuracy: 0.9905
# Epoch 43/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0149 - accuracy: 0.9984 - val_loss: 3.0083 - val_accuracy: 0.9871
# Epoch 44/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 2.8520 - val_accuracy: 0.9906
# Epoch 45/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 3.3106 - val_accuracy: 0.9879
# Epoch 46/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 2.3211 - val_accuracy: 0.9894
# Epoch 47/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 2.3103 - val_accuracy: 0.9898
# Epoch 48/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 1.9550 - val_accuracy: 0.9882
# Epoch 49/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 1.7617 - val_accuracy: 0.9895
# Epoch 50/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0095 - accuracy: 0.9990 - val_loss: 1.9152 - val_accuracy: 0.9889
# Epoch 51/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 1.4880 - val_accuracy: 0.9898
# Epoch 52/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 2.1037 - val_accuracy: 0.9889
# Epoch 53/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 1.9467 - val_accuracy: 0.9897
# Epoch 54/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 2.0229 - val_accuracy: 0.9908
# Epoch 55/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0102 - accuracy: 0.9993 - val_loss: 2.1992 - val_accuracy: 0.9903
# Epoch 56/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0043 - accuracy: 0.9996 - val_loss: 2.0740 - val_accuracy: 0.9898
# Epoch 57/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 4.0720 - val_accuracy: 0.9875
# Epoch 69/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 6.3420 - val_accuracy: 0.9898
# Epoch 70/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 6.2905 - val_accuracy: 0.9899
# Epoch 71/150
# 469/469 [==============================] - 11s 24ms/step - loss: 6.0368e-04 - accuracy: 0.9998 - val_loss: 6.1102 - val_accuracy: 0.9899
# Epoch 72/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0106 - accuracy: 0.9991 - val_loss: 6.6522 - val_accuracy: 0.9871
# Epoch 73/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 7.1847 - val_accuracy: 0.9905
# Epoch 74/150
# 469/469 [==============================] - 11s 24ms/step - loss: 3.2484e-04 - accuracy: 0.9999 - val_loss: 7.7993 - val_accuracy: 0.9904
# Epoch 75/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.0314e-05 - accuracy: 1.0000 - val_loss: 7.8605 - val_accuracy: 0.9907
# Epoch 76/150
# 469/469 [==============================] - 11s 24ms/step - loss: 3.0924e-06 - accuracy: 1.0000 - val_loss: 7.8486 - val_accuracy: 0.9907
# Epoch 77/150
# 469/469 [==============================] - 11s 24ms/step - loss: 9.5456e-06 - accuracy: 1.0000 - val_loss: 7.9051 - val_accuracy: 0.9907
# Epoch 78/150
# 469/469 [==============================] - 11s 24ms/step - loss: 2.1479e-04 - accuracy: 1.0000 - val_loss: 8.1163 - val_accuracy: 0.9911
# Epoch 79/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0067 - accuracy: 0.9991 - val_loss: 7.5025 - val_accuracy: 0.9904
# Epoch 80/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0125 - accuracy: 0.9987 - val_loss: 9.5557 - val_accuracy: 0.9898
# Epoch 81/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 7.8932 - val_accuracy: 0.9900
# Epoch 82/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 9.3179 - val_accuracy: 0.9883
# Epoch 83/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0044 - accuracy: 0.9996 - val_loss: 8.2080 - val_accuracy: 0.9887
# Epoch 84/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 7.9422 - val_accuracy: 0.9886
# Epoch 85/150
# 469/469 [==============================] - 11s 24ms/step - loss: 7.3773e-04 - accuracy: 0.9998 - val_loss: 8.1238 - val_accuracy: 0.9892
# Epoch 86/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 7.8962 - val_accuracy: 0.9899
# Epoch 87/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 9.5102 - val_accuracy: 0.9862
# Epoch 88/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 9.1164 - val_accuracy: 0.9895
# Epoch 89/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 6.9281 - val_accuracy: 0.9896
# Epoch 90/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 7.9896 - val_accuracy: 0.9910
# Epoch 91/150
# 469/469 [==============================] - 11s 24ms/step - loss: 5.3675e-04 - accuracy: 0.9999 - val_loss: 7.2222 - val_accuracy: 0.9908
# Epoch 92/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 7.4733 - val_accuracy: 0.9896
# Epoch 93/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0053 - accuracy: 0.9996 - val_loss: 7.9292 - val_accuracy: 0.9898
# Epoch 94/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 8.3231 - val_accuracy: 0.9903
# Epoch 95/150
# 469/469 [==============================] - 11s 24ms/step - loss: 4.4775e-04 - accuracy: 0.9999 - val_loss: 8.2308 - val_accuracy: 0.9903
# Epoch 96/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.6594e-04 - accuracy: 0.9999 - val_loss: 7.6128 - val_accuracy: 0.9902
# Epoch 97/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.3948e-04 - accuracy: 0.9999 - val_loss: 7.5245 - val_accuracy: 0.9902
# Epoch 98/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 6.4273 - val_accuracy: 0.9892
# Epoch 99/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 6.0906 - val_accuracy: 0.9906
# Epoch 100/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0052 - accuracy: 0.9996 - val_loss: 5.6584 - val_accuracy: 0.9889
# Epoch 101/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 6.5315 - val_accuracy: 0.9902
# Epoch 102/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 6.4517 - val_accuracy: 0.9895
# Epoch 103/150
# 469/469 [==============================] - 11s 24ms/step - loss: 3.3640e-04 - accuracy: 0.9999 - val_loss: 6.2003 - val_accuracy: 0.9908
# Epoch 104/150
# 469/469 [==============================] - 11s 24ms/step - loss: 4.5527e-06 - accuracy: 1.0000 - val_loss: 6.2159 - val_accuracy: 0.9908
# Epoch 105/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.5252e-06 - accuracy: 1.0000 - val_loss: 6.2036 - val_accuracy: 0.9908
# Epoch 106/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 6.2030 - val_accuracy: 0.9869
# Epoch 107/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 7.0856 - val_accuracy: 0.9889
# Epoch 108/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0063 - accuracy: 0.9993 - val_loss: 8.5141 - val_accuracy: 0.9895
# Epoch 109/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0041 - accuracy: 0.9996 - val_loss: 8.8461 - val_accuracy: 0.9898
# Epoch 110/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 8.9693 - val_accuracy: 0.9893
# Epoch 111/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 10.2898 - val_accuracy: 0.9894
# Epoch 112/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 9.5003 - val_accuracy: 0.9894
# Epoch 113/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 9.2113 - val_accuracy: 0.9898
# Epoch 114/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 4.4513 - val_accuracy: 0.9876
# Epoch 115/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 3.9407 - val_accuracy: 0.9893
# Epoch 116/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 4.1524 - val_accuracy: 0.9897
# Epoch 117/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 3.6861 - val_accuracy: 0.9878
# Epoch 118/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0061 - accuracy: 0.9997 - val_loss: 3.5641 - val_accuracy: 0.9899
# Epoch 119/150
# 469/469 [==============================] - 11s 24ms/step - loss: 6.9008e-04 - accuracy: 0.9998 - val_loss: 3.5898 - val_accuracy: 0.9900
# Epoch 120/150
# 469/469 [==============================] - 11s 24ms/step - loss: 5.6985e-05 - accuracy: 1.0000 - val_loss: 3.5266 - val_accuracy: 0.9898
# Epoch 121/150
# 469/469 [==============================] - 11s 24ms/step - loss: 2.0301e-06 - accuracy: 1.0000 - val_loss: 3.5341 - val_accuracy: 0.9901
# Epoch 122/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.2646e-06 - accuracy: 1.0000 - val_loss: 3.5508 - val_accuracy: 0.9900
# Epoch 123/150
# 469/469 [==============================] - 11s 24ms/step - loss: 4.3513e-06 - accuracy: 1.0000 - val_loss: 3.5594 - val_accuracy: 0.9903
# Epoch 124/150
# 469/469 [==============================] - 11s 24ms/step - loss: 2.1550e-06 - accuracy: 1.0000 - val_loss: 3.5536 - val_accuracy: 0.9900
# Epoch 125/150
# 469/469 [==============================] - 11s 24ms/step - loss: 9.2335e-04 - accuracy: 0.9998 - val_loss: 3.7583 - val_accuracy: 0.9892
# Epoch 126/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0098 - accuracy: 0.9992 - val_loss: 2.9484 - val_accuracy: 0.9883
# Epoch 127/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0089 - accuracy: 0.9991 - val_loss: 4.9419 - val_accuracy: 0.9883
# Epoch 128/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 5.6673 - val_accuracy: 0.9894
# Epoch 129/150
# 469/469 [==============================] - 11s 24ms/step - loss: 6.3562e-04 - accuracy: 0.9999 - val_loss: 5.7687 - val_accuracy: 0.9896
# Epoch 130/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 6.1259 - val_accuracy: 0.9893
# Epoch 131/150
# 469/469 [==============================] - 11s 24ms/step - loss: 4.1276e-04 - accuracy: 0.9999 - val_loss: 5.4189 - val_accuracy: 0.9900
# Epoch 132/150
# 469/469 [==============================] - 11s 24ms/step - loss: 4.0877e-04 - accuracy: 0.9999 - val_loss: 5.1941 - val_accuracy: 0.9899
# Epoch 133/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.1702e-04 - accuracy: 1.0000 - val_loss: 5.2505 - val_accuracy: 0.9901
# Epoch 134/150
# 469/469 [==============================] - 11s 24ms/step - loss: 7.7514e-07 - accuracy: 1.0000 - val_loss: 5.1901 - val_accuracy: 0.9900
# Epoch 135/150
# 469/469 [==============================] - 11s 24ms/step - loss: 4.3873e-07 - accuracy: 1.0000 - val_loss: 5.2199 - val_accuracy: 0.9899
# Epoch 136/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.7083e-07 - accuracy: 1.0000 - val_loss: 5.1943 - val_accuracy: 0.9901
# Epoch 137/150
# 469/469 [==============================] - 11s 24ms/step - loss: 2.0463e-06 - accuracy: 1.0000 - val_loss: 5.2192 - val_accuracy: 0.9900
# Epoch 138/150
# 469/469 [==============================] - 11s 24ms/step - loss: 3.0889e-06 - accuracy: 1.0000 - val_loss: 5.2392 - val_accuracy: 0.9897
# Epoch 139/150
# 469/469 [==============================] - 11s 24ms/step - loss: 2.0958e-07 - accuracy: 1.0000 - val_loss: 5.2293 - val_accuracy: 0.9899
# Epoch 140/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.2205e-07 - accuracy: 1.0000 - val_loss: 5.2364 - val_accuracy: 0.9901
# Epoch 141/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.6774e-07 - accuracy: 1.0000 - val_loss: 5.2538 - val_accuracy: 0.9902
# Epoch 142/150
# 469/469 [==============================] - 11s 24ms/step - loss: 6.1516e-08 - accuracy: 1.0000 - val_loss: 5.2250 - val_accuracy: 0.9903
# Epoch 143/150
# 469/469 [==============================] - 11s 24ms/step - loss: 7.5026e-08 - accuracy: 1.0000 - val_loss: 5.2502 - val_accuracy: 0.9903
# Epoch 144/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.4457e-07 - accuracy: 1.0000 - val_loss: 5.2495 - val_accuracy: 0.9904
# Epoch 145/150
# 469/469 [==============================] - 11s 24ms/step - loss: 1.4336e-08 - accuracy: 1.0000 - val_loss: 5.2522 - val_accuracy: 0.9904
# Epoch 146/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 31.4055 - val_accuracy: 0.9882
# Epoch 147/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0140 - accuracy: 0.9988 - val_loss: 24.1182 - val_accuracy: 0.9887
# Epoch 148/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0168 - accuracy: 0.9990 - val_loss: 24.1818 - val_accuracy: 0.9880
# Epoch 149/150
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 21.8565 - val_accuracy: 0.9878
# Epoch 150/150
# 469/469 [==============================] - 11s 24ms/step - loss: 2.4273e-04 - accuracy: 0.9999 - val_loss: 22.3848 - val_accuracy: 0.9894

# %%
y_held_pred=model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
y_pred=np.argmax(y_held_pred, axis=1)
y_test_1=np.argmax(y_test, axis=1)

print(y_test_1.shape)
print(y_pred.shape)
# Out:
# (10000,)
# (10000,)

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 22.3848 - accuracy: 0.9894
# [22.38478660583496, 0.9894000291824341]

# %%
his=model.evaluate(x_test, y_test, verbose=2);
print(his)
# Out:
# 313/313 - 1s - loss: 22.3848 - accuracy: 0.9894 - 1s/epoch - 3ms/step
# [22.38478660583496, 0.9894000291824341]

# %%
y_held_pred_train=model.predict(x_train)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step

# %%
y_pred_train=np.argmax(y_held_pred_train, axis=1)
y_train_1=np.argmax(y_train, axis=1)

print(y_train_1.shape)
print(y_pred_train.shape)
model.evaluate(x_train, y_train, verbose=2);
# Out:
# (60000,)
# (60000,)
# 1875/1875 - 6s - loss: 1.0329e-05 - accuracy: 1.0000 - 6s/epoch - 3ms/step

# %%
import seaborn as sns

sns.regplot(x=y_train_1,y=y_pred_train, label="Training Data")

plt.xlabel('Actual G*')
plt.ylabel('Predicted G*')
plt.title('Actual vs. Predicted')
plt.legend(loc="upper left")

sns.regplot(x=y_test_1,y=y_pred, label="Testing Data")
# Out:
# <Axes: title={'center': 'Actual vs. Predicted'}, xlabel='Actual G*', ylabel='Predicted G*'>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_grand_truth = y_test
y_predicted = np.argmax(y_predicted,axis=1)
y_grand_truth = np.argmax(y_grand_truth,axis=1)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_grand_truth, y_predicted)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
f, ax = plt.subplots(figsize=(15,15))
sns.heatmap(cm,fmt=".0f", annot=True,linewidths=0.2, linecolor="purple", ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Grand Truth")
plt.show()

# %%
scores = np.zeros((10,3))
def calc_F1(num):
  TP = cm[num,num]
  FN = np.sum(cm[num,:])-cm[num,num]
  FP = np.sum(cm[:,num])-cm[num,num]
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  F1_score = 2*(recall * precision) / (recall + precision)
  return precision, recall, F1_score
for i in range(10):
   precision, recall, F1_score = calc_F1(i)
   scores[i,:] = precision, recall, F1_score
scores_frame = pd.DataFrame(scores,columns=["Precision", "Recall", "F1 Score"], index=[list(range(0, 10))])

# %%
f, ax = plt.subplots(figsize = (4,10))
ax.set_title('Number Scores')
sns.heatmap(scores_frame, annot=True, fmt=".3f", linewidths=0.5, cmap="PuBu", cbar=True, ax=ax)
bottom, top = ax.get_ylim()
plt.ylabel("")
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
# Functions: Performance Evaluation 

def Performance(Model , y_predd): 
    
    # model accuracy
    accuracy = accuracy_score(y_test_1, y_predd)
    print( Model +' Accuracy:'+'\033[1m {:.2f}%'.format(accuracy*100))
    
    # model Classification Report
    print('\nClassification Report: '+'\033[0m')
    print('*' * 22)
    print(classification_report(y_test_1, y_predd))

# %%
Performance('CNN' , y_pred)
# Out:
# CNN Accuracy: 98.94%
#
# Classification Report:
# **********************
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1000
#            1       0.98      0.99      0.99      1000
#            2       0.98      0.99      0.98      1000
#            3       0.98      0.99      0.99      1000
#            4       1.00      0.99      0.99      1000
#            5       0.98      0.98      0.98      1000
#            6       1.00      0.99      1.00      1000
#            7       1.00      0.99      0.99      1000
#            8       1.00      0.99      1.00      1000
#            9       1.00      0.99      0.99      1000
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ###
